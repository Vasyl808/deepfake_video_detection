# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasyl808/deepfake_video_detection/blob/main/fakeavceleb(train_test_split)_balanced_ready.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.6)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.10)

# %%
# !mkdir ~/.kaggle
# !touch ~/.kaggle/kaggle.json

api_token = {"username":"vasylhunia","key":"ac16ba802a4f035043401d0f06d03422"}

import json

with open('/root/.kaggle/kaggle.json', 'w') as file:
    json.dump(api_token, file)

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install facenet_pytorch --no-deps
# Out:
# Collecting facenet_pytorch
#   Downloading facenet_pytorch-2.6.0-py3-none-any.whl.metadata (12 kB)
# Downloading facenet_pytorch-2.6.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 24.8 MB/s eta 0:00:00
# Installing collected packages: facenet_pytorch
# Successfully installed facenet_pytorch-2.6.0

# %%
from kaggle.api.kaggle_api_extended import KaggleApi


api = KaggleApi()
api.authenticate()
api.dataset_download_files('kangjiayong/deepfake-detection', path='./data', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/kangjiayong/deepfake-detection

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('/content/data/selected_video.csv')

df
# Out:
#      label       file_name                                               path
# 0     FAKE  qudhlvaxtc.mp4  D:\OneDrive - Asia Pacific University\Degree Y...
# 1     FAKE  jzxzzmcplq.mp4  D:\OneDrive - Asia Pacific University\Degree Y...
# 2     FAKE  pydbvfkslp.mp4  D:\OneDrive - Asia Pacific University\Degree Y...
# 3     FAKE  vytklfqusv.mp4  D:\OneDrive - Asia Pacific University\Degree Y...
# 4     FAKE  dbzpqxlahq.mp4  D:\OneDrive - Asia Pacific University\Degree Y...
# ...    ...             ...                                                ...
# 5019  REAL  znlzegqkbp.mp4  D:\OneDrive - Asia Pacific University\Degree Y...
# 5020  REAL  rzytdiivhu.mp4  D:\OneDrive - Asia Pacific University\Degree Y...
# 5021  REAL  icffpvvtnu.mp4  D:\OneDrive - Asia Pacific University\Degree Y...
# 5022  REAL  ucidfsqdkw.mp4  D:\OneDrive - Asia Pacific University\Degree Y...
# 5023  REAL  mhpavogfxb.mp4  D:\OneDrive - Asia Pacific University\Degree Y...
#
# [5024 rows x 3 columns]

# %%
len(df['file_name'].unique())
# Out:
# 5024

# %%
import json
import os


def conver_path(path: str):
    if '00' in path:
        path = path.replace('00', '0')
        return path
    if '01' in path:
        path = path.replace('01', '1')
        return path
    if '02' in path:
        path = path.replace('02', '2')
        return path
    if '03' in path:
        path = path.replace('03', '3')
        return path
    if '04' in path:
        path = path.replace('04', '4')
        return path
    if '05' in path:
        path = path.replace('05', '5')
        return path
    if '06' in path:
        path = path.replace('06', '6')
        return path
    if '07' in path:
        path = path.replace('07', '7')
        return path
    if '08' in path:
        path = path.replace('08', '8')
        return path
    if '09' in path:
        path = path.replace('09', '9')
        return path


result = []
for _, row in df.iterrows():
    file_name = row['path']
    path_parts = []
    start = 0
    separator = '\\'

    for i, char in enumerate(file_name):
        if char == separator:
            path_parts.append(file_name[start:i])
            start = i + 1
    path_parts.append(file_name[start:])
    curr_path = path_parts[-1].replace('.zip', '')
    file_path = os.path.join('/content/data', row['label'], row['label'], conver_path(curr_path), row['file_name'])
    result.append((file_path, row['label']))

result
# Out:
# [('/content/data/FAKE/FAKE/dfdc_train_part_9/qudhlvaxtc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/jzxzzmcplq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/pydbvfkslp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/vytklfqusv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/dbzpqxlahq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/uqkdiusxtz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/snphlfsrmr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/ohofmyydou.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/mhodpmscfi.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/hfhgtkuaxr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/njgymtktgd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/sclvdumbkh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/lnfcazoshs.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/pwduwistqx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/dkrknynayu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/pgeibxkxri.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/dmdhwpgbtx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/xnwxjbzlfr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/dwnjghnnvx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/ndfrtxtzvb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/lzggfqecvr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/cjhwsuzeuz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/jzzcskarto.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/omtnalawgc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/vnldthxqbz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/mtmutriwai.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/dimizkqjfg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/xonsffcpsi.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/tfrtdisjbp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/rjyuimecje.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/avovhmumnp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/cpxedkyytp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/jqdxklmzfb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ftzqxzwwur.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/dnhtodemdj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/xkmhhsbilj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/tbvugeywtg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/kufrfqqulg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/fttesiqzki.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/tuxbzsrszr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/pwkcllsrft.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/grncxndcog.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/vdkyloetfp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/gqnaxievjx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/zbchoijdka.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/zumqskdmht.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/vzocjdjdcg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/rsxhaufcfc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/xbmcmbhtnx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/ubfimnnqyw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/qsrzkstona.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/wtxudtaebc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/cevontacue.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/vvixicbzkx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/kygwadghkz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/rftqyddfmd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/bnnpurjrvu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/tjgqkseyta.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/tvvzvvwicn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/bithritjse.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/pdgjupwbjd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/jfiqnujzis.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/uwfwsprjoo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/hyhntnfids.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/fbkmcokyez.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ofeedkhgvm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/cqqapjnjkx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/nyishxxncb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/efrvcykret.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/kfvyomcqkz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/xlmduthjih.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/kmhiqddyhh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/swflsqlknt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/jgaejvfomy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/xjeavrnqry.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/qrvrwipzgv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/qsrahhgpky.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/lwehwetpgq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/yqlussxvno.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/lqbomwknem.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/pkjhgyadnk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/dhpbcfmalj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/cicgeotuuw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/hgadfwdhce.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/ylzzdvlkuj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/bsqnzpidrn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/fzgisyxqhy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/cwlwyjtxnc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/xkwjjjkcam.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/oqnpzvjsac.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/mbarbaitxt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/xvxhxmbopd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/pjqxxtafix.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/hoopxglgxr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/qmfxxsppvd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/lrhwwlrhjc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/rqxiddngke.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/tadsvlhcrp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/foftbpkdev.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/ftwkdcwsvc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/icklgrlvqs.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/qctcumfqty.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ksyknkfzuv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/glbjtxmsqn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/odlejjfjaj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/eisofhptvk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/udhrnsnbmb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/cqzpcuukhp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/uvfkppqsjy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/pjlswenrwb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/uajjhgjkbr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/mgcxitynzu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/owqtpqsqkq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/uylukcctgv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/iyzfltopuo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/vjwebqvvfz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/mzfdaznsek.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/rcovjvmlcu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/hvngotpack.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/xhwacojjdg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/lkformlpas.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/dzezotgbhf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/nwzwoxfcnl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/jrganooivc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/tbomjqtdyd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/mkbnkdnzoh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/wswmgmtfnc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/zgpxvrspxj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/rnhyfmjlfx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/beosdmoipb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/bgtgxubqmy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/taiosvirky.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/eescbdtoom.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/vfqvqdnjtf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/vyismybxnv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/plqyhhhosp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/ybpjsisfqg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/dngvaozylo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/fhdkuglmzo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/czstpmzduw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/dargqdtmnl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ndedatonaa.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/embxvesuyh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/uumdjtwgel.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/htftegewhf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/beoobdybbw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/gwaxqwlsww.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/bwkddsdoqj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/opxdqaecvm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/gmvebzkncg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/jfbeqfotli.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/ugpgxcljaj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/duczhwighk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/lnkyzfeuwl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/lpsypztflr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/iverfkizcj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/zqandetlod.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/mtnzllsqcw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/fwwrivmuqh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/sjyacyfblj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/dkknwsvdgo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/amkqhexhou.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/kokjdjaraq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/hmjiojxgwm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/ultbrsqruz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/zdnhrmqxvu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/ihjcmhvqkl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/dhyybsrvwc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/wdgzjksmht.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/pseatxfbza.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/djeichwqqe.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/eupisnxhsb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/htmqemvoqv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/xojuahsfdv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/rwnhjiliro.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/lmrqxokzqo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/ukvkdkkdtm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/dlealirddu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/gvxiqjjkab.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/fjptcjjdve.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/niffjezaqu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/epgwtbcrmp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/nxzgekegsp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/fkdghyvcvc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/mnqidylcpm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/dkuqbduxev.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/pngnzctffz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/bgnxtocxqo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/fsouqkhmkp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/gogybqjoqi.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/uyvzsejsbq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/ltvulvzjwr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/qtkewtsleu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/ptqthgwsnt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/bjtdbxvwfp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/bavaszoflz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/gmonvwaujc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/tbkloilqkg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/embmaestpq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/vbqasscuva.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/funlmeoodq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/iplrrxmwgt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/rlnhkhvaaf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/gyaqwfujgg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/occipikyys.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/hmrqnkxows.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/pjzniyytro.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/thmwcolqan.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/fdqfqujbqh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/xpfnwshfju.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/gqsczmyvlj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/hirpijibhp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/ktrleojxlf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/zclfdeovzw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/veyaiqvubs.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/xbctgvzitp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/gbvpnqitbh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/fxredodlkl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/kxkpozbwhz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/bdvqwpqmag.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/rewyhkernx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/xswdwufkyy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/zmsjlvvwsu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/vpskcoeyfw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/bdgcinijzt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/kqfaiaxafz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/gjqsogruom.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/ugbkexlzgv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/mjkxlihigq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/odgtjsijuv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/nemimkngst.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/mshechsves.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/fphuxwdtpy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/awlskxaayc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/fbflejhfpn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/jhomwnydeg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/xcigzlpywx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/ibvomadohg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/ovogkdhknn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/pfmnqiwfvv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/qcjwsygnxe.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/tiwunihtno.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/tujnmixmiw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/eslgzuvzya.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/skbekcwkne.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/pmpdirnxaj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/phoxxwoozc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/jwllclsfup.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/pbpgyiimwt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/gddgbvubhq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/sochqsfsow.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/zqyhebqeno.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ixggoemcbu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/htljbnzazk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/hbfabhtqsd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/agrzhzapku.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/zdunpeofrd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/vwcdgwdecc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/ftdjicutax.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/upfgdyshre.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/veyejigaka.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/uudrzpnzdr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/mdulkdtlsv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ukfleerauf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/tqdocbbvgq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/ddlsxsesbx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/axgjecgvwm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/ifbfpcfynf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/ohtngifnek.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/bgyrspukmk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/gptrgbtqem.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/hxburehncr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/qxkhbvpomm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/lobxktzhbg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/jahvruaepm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/ojagblcuat.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/opizockopw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/uexmgefzxy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/zrkkrxpxtf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/gloxelyhst.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/urhzdfzsqa.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/seddxiphzu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/nazagsglnq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ppegxwyrxb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/pksjrtzppp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/nahxuegxhp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/wukdfhaovv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/cxmvedvusk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/bqdpxnfcsu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/onampwjnne.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/mutfpfruab.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/gdwjwgbyse.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/connsjyvsl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/hiclqqebky.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/wkajsuweae.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/bxptafpclo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/xpxrjwwibn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/gnpaehuyie.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/djhncpdcmo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/nniurlhwwy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/gagilukzul.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/fakcmcbsax.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/duxebrvpko.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/gomxkjifiu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/shxwuzwonb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/mjetzeswnn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/nttcjrrynk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/enxmvehfvn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/shuwtkriuy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/fiwxyfsijh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/dekkxfgplf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/yuephcvqzq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/doxxwkyeyy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/yxdnfmtmkc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/knxamupysc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/npghatigbw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/hoyudeuckw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/egcasqzjep.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/oaxnzhyvuw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/exioersgps.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/olheajbvle.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/ygbnyzdsrm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/wlsutxwtqb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/ksquagjhxq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/ofbgurmlpw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/hqeevyeknb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/rwnyguelho.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/hsbrwaeaah.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ypzynpqiga.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/zvzwzdjikh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/wdhvvkuwuq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/tkwsiwrfut.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/jrnmspakke.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/jicebollua.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/ziozendwlt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/nobtuwxcqf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/zbymcnlvka.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/cerwqpmouj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/sjmqjqzbli.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/opyychqzhz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/xnhsjbzmux.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/dqqwmmwlbg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/bneqwtomed.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/ajozokmfyd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/fkwgnwgfkj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/vdcefzukbf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/emedkscdtu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/sigrlwzhlf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ucxjlujwfm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/zloicyfcxr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/omonptfuas.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/ywbltzuaet.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/kezfzeblfg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/lxubdzurrp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/mroviqmznc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/qdqdsaiitt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ktcdysrkpp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/gudedkpnie.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/dyiixvqmjt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/hbcmorypjy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/cujsfckgxq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/iluitobthi.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/ydqeopjemz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/yprhthcacq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/jcsetstuio.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/xjxgmbkkxe.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/rbuxdgaatz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/kyxmtfyceu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/romzqwhhlb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/ddkbgdbmud.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/ldmoodikzl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/qhtwtxvlan.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/xofazlfwia.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/lpdnvmgtrg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/iojdmuyccj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/mbqpmbgxve.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/djgspuaqqp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/dpjfwtafke.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/zqncvydvvs.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/mqukycwlwj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/ozxrqttooz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ijvqpzanqe.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/agetriarxi.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/rwtpwyzvdt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/ipeujcomet.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/crnkpgykgj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/nbjtqxnzet.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/gplfvateud.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/wnmqfppwxs.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/nndtplomqk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/dbqrktaaub.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/vqkxybvvdt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/lhhqmvyaax.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/qcsuzqqohv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/jpyppltqju.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/rtaajqrbds.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/dlthzbremc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ocleckhcbx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/rcytnuefvt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/guthpzsxmr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/ojffloftih.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/miwsnvijjt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/bfmvjimrqn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/tzoiwglzin.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/whsjrsjfzu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/iimnvjpgoy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/xposltkzgy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/vkdodrhzpd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/wbtxxrwhah.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ggspsadinj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/fbenvdzzqa.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/bpqrwvichd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/vtzlfurays.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/nioeronoih.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/icbqfvgfsm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/bzuszivgau.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/djlpswbquk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/gmdoyjvcnu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/eeyomeqcox.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/auuxrdogjl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/uxynygwdiu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/azqiqdmeif.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/brxksmkyrv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/aidnmtgwlv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ybpsqaindb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/eqslzbqfea.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/ikhlmfaaev.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/nrejgewmad.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/rckrviuyuy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/rqckrhzqqc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/rmckaifnnp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/xnmmweqmdt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/huodbvioih.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/ghxzvovygq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/sxfppsverr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/dwrpxabjqt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/gcnbfzgtnd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/dneleizoxr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/ommvnsljtz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/kcxziwytym.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/sqklwyntht.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/fiqhctxfus.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/sxfmhtwazr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/bhbnvkiwti.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/hnrejhehka.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/ppkzpkiart.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/wrentldfhl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/kfhmhoxjtx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/xfmkawnodd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/jzxjrsafrx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/mhfooaulrx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/djbfwqsvsb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/wcdspbjwpe.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/dwhobkntoq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/duciovvndy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/jranrlmuyk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/irwcschyys.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/fjxynzqzxc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/nxhlsqkxfv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/rqhkeugxad.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/roqbnlondz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/lwtgwggkpb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/rucctscaqp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/mldxkftymx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/lbqwonpufw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ktzvbxfzmx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/fhsdyqtcja.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/kiyuduxzuc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/yeuembthmr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/skuvjoyukn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/amvhbsiwou.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/xelbexhxyr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/sbxbsiwwnc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/cotvlcroov.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/tuwpriwvid.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/enzngcerxy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/lzkddbpqno.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/xvrmugrctg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/kfjalioqsz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/sfjmwcolyd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/syqmrinrir.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/mmsxambsmi.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/jxwkqvpvwf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/eunmohsjhe.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/ewqlqvleil.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/eutcmnwsum.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/rafuugjdfn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/xccznjimgh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/ibxfxggtqh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/kkybwlfzph.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/kstmekinaw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/kacwtblcdu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/kswzebpkwi.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/iyswglziib.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/uywpnxqqne.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/rgbdumupgz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/tsvkpzczfu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/kcqxkdwdjv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/arpsbojfxl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ygtakodngl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/rzqleunkcn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/xaeiqjajxf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/vltwlzqcph.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/ggeiapygvj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/jwrjdjviqe.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/wowbfgzyiz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/fjiokipniq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/buhqsrexai.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/kvnxaqrjgf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/bfcmnlwsiq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/bweepvlxli.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/roltkgcnoc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/gmutjqhliq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/ejmicbsvfd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/sgbkpxoqko.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/kqjsssjqll.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/spsyaiylsd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/bdpwzkrofr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/hoxemyczix.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/iehcphzizv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/fgyjlqhugm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/khicvwooti.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/qeefkatpus.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/vfquueicnw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/jsbitxrabi.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/hwcrgnzkyv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/exjhxchdsg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/qjppdsmwxc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/houzrrfbqg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/wiqxnnotxa.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/vqvqmnomhv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/tfprsyrhjj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/mspsqvowvr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/ubsmsgyakt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/zfnluuhkuw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/xvgkojxxwd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/iaoudvakbo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/zmciyeiebe.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/fhzqmyagac.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/afcxyiwatf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/xldcwunomk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/yyslirpggv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/gqnzocbvpg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/xxbvyfyvqr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/pdebgrasgr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/ctqmvgzvfa.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/lllektdbny.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/gvlraqlweh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/wpdlxgyoim.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/jsjuuscwnp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ftfiuxqnrq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/rgcplyuqwy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/gglukbwbin.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/cceclbhgej.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/evvacwqxzb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/llmlqisnfq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/hcnqndljfc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/xfyhleqdwz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/nuumrezfak.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/ropvlealpl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ruprvdicng.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/aydhuyhqvh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/ibxkammjrt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/osopquegkp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/zypkaxiras.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/owvtmwlouu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/sxtiprymmc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/noynlqeman.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/juhdvgqdfe.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/zywnhhdcku.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/dzwleiudsk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/uikpmbsozb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/ynnannlllo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/fiiulonszn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/mmjdrqyjpg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/eqmokglwxl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/mvereewiyq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/nwapznmmfx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/bseaalaspv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/obwygkicpv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/ocguwrotdy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/yajhwipypq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/hmuxqdecfs.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/dmaqwzrgkr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/dvlfqigkgr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/rhrgxyrizv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/zaqsqscuhr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/kajzbtxqdk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/birmbtezni.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/uekvmpoqdv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/awkzxzryod.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/lwlpjzobjr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/swfbbdgult.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/rtlnmevktw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/jzbrpejxia.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/ieprixgtqw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/lvgezhrkez.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/cmvncstbkx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/uurysjbcwn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/sirsquaduu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/drmtykanjz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/iqpauxrmqa.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/plsumwddmu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/yhmbjbljst.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/jtteetuqtt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/ezxjmgjnyz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/krrxfxqahs.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/pkudbxhyss.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/mzxtfngffh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/ujwsgcseyo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/atubuiqpqo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/zynjzuvcpx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/erzyucrekk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/blxtweqoax.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/pqavaksffx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/nhodnuetwx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/pzddciqvlv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/gocuchujbg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/ipnlndiupb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/zpihvtiias.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/aofwudrvjp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/wixmimgsqb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/plimntivef.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/jukcjryufw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/auldikrfnu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/kmrojywxvz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/tagbkqoodp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/elgsweyjfb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/vwdveepjhm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ddnishdmey.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/asntcqtqkq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/vcboelljsh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/liloryfkmk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/bspvtixfud.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/yphbsgjuwt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/fcsldkukwf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/yvrezovjkj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/pzecuoitxn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/sdrbksvvee.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/plkbyavvqp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/qpgxsixzag.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/ipetzkwdir.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/isoiooeznt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/gkqzhnqfxo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/ssitlrruir.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/hylqmhztng.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/kvilddnlfx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/vvvchefpra.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/tmhmzccmql.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/yxuqretfae.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/psjvaeamke.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/wffenwrkeq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/qjgwlbctqa.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/ctulsxsjwx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/mjhtykeebu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/kxvcunmyed.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/yrnvzuotht.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/xzoeyqarko.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/iesxfvntdp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/yminuwlmoh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/mfkzoapcqm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/bnynincvkz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/ezczrzbsgq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/umruvgbthd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/ptgpqdnxtd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/mpjumjlgsu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/cgrqqpzjzd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/wydbwjnxak.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/fqxionszxk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/kkpddzaexu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/lvglcazbst.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/hncakxzmou.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/gpskwigkxd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/rirymstiia.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/qdrjugpyhy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/kgeeivvuhe.mp4', 'FAKE'),
# ...
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/xlzcdtjiwk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/ptejxhztrw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/zzivhztyyn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/ztwernvlim.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/frlsxhdntt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/utdqvtzcwx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ycklqgnxkb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/osxjcahnfz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/pktiwqqjrt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/uxdxfnvvvq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ozixsxpjkw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/eahoycmeem.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/hyytqwxhei.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/xqzrxatnwy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/nhknkdzana.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/knkuclzcpq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/uqidvkpfxa.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/suzswficla.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/qrizbzenzg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/zenpspbukk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/fwtfiussmt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/lvnylzfwdl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/rhcppchebc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/zuojsaztso.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/puvpowzusj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/fagdrfcvcf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/qythavtvdw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/jstwvimaml.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/zbxcinckka.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/mlivldbdxg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/llypatkcie.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/qlbphfahuf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/xqvxxnucbo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/hgqmrwnyiy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/upqhelowpp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/vuzbfohkwg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/fbpmpbqcxf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/eopsexsidw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/jkcpgrzvdc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ctvgzogjqz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/dtvmqghkxl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/ayfjanopir.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/rtkdqnqzhc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/ogznalgvrd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/dywrvfnhme.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/tivksreuuj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/cyywjpwwdn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/bylxcfxqaf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/grielfiuwt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/wpvnnqoqvc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/rooztlscpz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/xynzctcfqe.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ibbvnkvvsx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/voanbpmarp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/ridiczlgdt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/lprzdqixuf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/zdihvtnqgi.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/kaojqcodsu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/vqxrpdyiii.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/gftdzhtvuc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/rswongbvxz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/vgdsgijqpv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/ijudojmrwt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/nryoehjuec.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/nulqhgmnir.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/dmoyfrklmr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/qjwltbnstb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/waaeyecbto.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/lrjngxxvqq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/wuhrhzdfyc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/hndlhsvgnj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/cuhbygmfxd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ptlwvhdjqb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/lsddhheqgb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/xttqggwaze.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ovnbtfrvau.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/foqfrkuztm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/jorfifqxhq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/vitakliaju.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/neonfkiuqa.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/eivtckqcmk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/dwgfrzahmr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/cdpukyvqpm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/kydkdomuqf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/lotjxrabtr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/mncikvahhj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/ppmyxrpxcf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/tlrnbcrjqg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/rpxnyljmsf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/cjetyhnwpr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/gtolbxsyzd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/qadqzqlgcf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/qdfoiguwaf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/dxgewerqli.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/ixbcqacrfk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/icsqwhmeou.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/ctzgudcdyu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/nwboifkqfm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/qdzlaqopsf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/moiehodfkl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/aytfwjmtkk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ptrldmvjvb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/xogkkrwhpx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/vrfmupvimm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/bjhlloopdo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/ycmxnievjv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/gabckzxoia.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/fkwucbqnot.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/hltqxlbmyl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/udhpbnlglb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ugjbxqirgl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/zrbyosbzub.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/pvvxzkkhfc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/frgcvppgzj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/beoftnkaok.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/aaqaifqrwn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/bdqrsasbda.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/yoswposjpb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/srzobeaavr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/srphznkrel.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/monumbirio.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/sychesiyyu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/ekadmectsi.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/fwsbbpbexg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/xbmgnchcfy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/goppdjjssf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/ridrlfphki.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/vwzaditkns.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/mhflwchqba.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/chgqmwtbyf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/tbsbklubov.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/jzmxmyafls.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/lzkcuidkvz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/barfpcdpxe.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/veoljutdiu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/nvwjgpgusw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/utfvrzienn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/roufopvnnp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/nqmyaryapl.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/wcuiivptnj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/hpomzutmfq.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/dsbrnbihpn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/tvjlounpor.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/vqegfnepqw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/olzrcqlblz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/grkspqjqfs.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/uavfzwknsp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/mckmotruyd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/gbdfukfadr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/hnelauuwfr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/hxgvckxrzo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/udpxeyppqp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/kwobmfatrm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/nlzfavdtdz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/ivrrtkfqyf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/exwyzmylhy.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/joqdmptvzn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/rspzzovuct.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/tbtckqxqtw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/qzexcszwqh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/rfpaqnoosd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/njqwtamryw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/dhazowlcun.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/begolhmsru.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/fgplkrwnhb.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/jvlmwvzpak.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/arudlrbjsm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/bxctteujhv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/wkevfzkbwg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/mxrpnkuhmd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/vlcbaytswm.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/rozowkykwk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/fljyoqhgcp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/axntzvpfmh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/eneofiltbk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/ejwvqbeyef.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/uasrterhcr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/hpsvdyikxk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/arvqhnzltg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/bzxesmhumc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/gfknxjnoyo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/loddwuxljh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/zifrfihcoo.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/vrxiifcnhg.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/zuktznezhv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/zitzfjzqfr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/yxkrhygdue.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/xleihiqgxt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/kvaelhhfgr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/rlqeqblpea.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/pbvbnklkjk.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/jhnjkjvwgd.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/xdnysbdtlf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/vmakjnpbmv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/woquabuqla.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/elyoskeeju.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/czdchuhbfe.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/obguslzouh.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/augwyjvlqa.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/exunhdbwmp.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/swhfjvxpad.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/qrgrezupjj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/yivueijxxz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/qkbywibxqf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/nizibcuznt.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/yftdilwuco.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_1/cctrhqvein.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/ijbkyrrgbu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/irnxtdqahj.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/ctsxxraruc.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_7/zgquddsedf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/hyjqolupxn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/zdgtyxwrnr.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/etxknonwli.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/hwncvqjgkz.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_0/jqypqwufdv.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_3/jlpowwswuu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/nosshgxzii.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_6/txlablpnaf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_5/ollpdsvksf.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/wmobvmntzu.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_4/fcukkebcyx.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_8/gocqhmthdw.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_9/hbtmtojhdn.mp4', 'FAKE'),
#  ('/content/data/FAKE/FAKE/dfdc_train_part_2/xlvneejsyd.mp4', 'FAKE'),
#  ...]

# %%
import pandas as pd

df = pd.DataFrame(result, columns=['video_path', 'label'])

# Перевірка отриманого DataFrame
print(len(df['video_path'].unique()))
print(len(df['label'].unique()))
# Out:
# 5024
# 2

# %%
df['label'].hist()
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split


train_data, test_data = train_test_split(
    df,
    test_size=0.2,  # Наприклад, 20% для тестового набору
    stratify=df['label'],  # Зберігає співвідношення класів
    random_state=42  # Для відтворюваності
)

# Перевірка кількості кожного класу у тренувальному та тестовому наборах
print("Кількість у тренувальному наборі:")
print(train_data['label'].value_counts())
print("\nКількість у тестовому наборі:")
print(test_data['label'].value_counts())
# Out:
# Кількість у тренувальному наборі:
# label
# REAL    2010
# FAKE    2009
# Name: count, dtype: int64
#
# Кількість у тестовому наборі:
# label
# FAKE    503
# REAL    502
# Name: count, dtype: int64

# %%
train_data
# Out:
#                                              video_path label
# 1614  /content/data/FAKE/FAKE/dfdc_train_part_5/wogc...  FAKE
# 4968  /content/data/REAL/REAL/dfdc_train_part_9/veya...  REAL
# 4579  /content/data/REAL/REAL/dfdc_train_part_8/fapk...  REAL
# 4606  /content/data/REAL/REAL/dfdc_train_part_8/mvkn...  REAL
# 4887  /content/data/REAL/REAL/dfdc_train_part_9/hlte...  REAL
# ...                                                 ...   ...
# 1135  /content/data/FAKE/FAKE/dfdc_train_part_6/kqyv...  FAKE
# 3556  /content/data/REAL/REAL/dfdc_train_part_5/imrp...  REAL
# 4819  /content/data/REAL/REAL/dfdc_train_part_9/gtxp...  REAL
# 2163  /content/data/FAKE/FAKE/dfdc_train_part_6/tfup...  FAKE
# 1776  /content/data/FAKE/FAKE/dfdc_train_part_0/vzoc...  FAKE
#
# [4019 rows x 2 columns]

# %%
train_data.to_csv("train_dataset.csv", index=False)
test_data.to_csv("test_dataset.csv", index=False)

# %%
import json
import os
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('train_dataset.csv')


result = {}
for _, row in df.iterrows():

    file_path = row['video_path']

    label = row['label']


    result[file_path] = {
        'label': label
    }


with open('output_balenced_train.json', 'w') as json_file:
    json.dump(result, json_file)

# %%
import json
import os
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('test_dataset.csv')


result = {}
for _, row in df.iterrows():

    file_path = row['video_path']

    label = row['label']


    result[file_path] = {
        'label': label
    }

with open('output_balenced_test.json', 'w') as json_file:
    json.dump(result, json_file)

# %%
import json
from collections import Counter

# Зчитування JSON файлу
with open('output_balenced_train.json', 'r') as json_file:
    data = json.load(json_file)

# Ініціалізація лічильника для підрахунку лейблів
label_counts = Counter()

# Підрахунок кожного лейбла
for item in data.values():
    label_counts[item['label']] += 1

# Вивід розподілу лейблів
for label, count in label_counts.items():
    print(f"Label: {label}, Count: {count}")
# Out:
# Label: FAKE, Count: 2009
# Label: REAL, Count: 2010

# %%
import cv2
import itertools
import json
import numpy as np
import pandas as pd
import random
from torch.nn import functional as F
import os.path
import time
import torch
from torch import nn
from torch.nn import functional
import glob
import datetime
import subprocess
from facenet_pytorch import MTCNN
import shutil
import matplotlib.pyplot as plt
from pathlib import Path


class FaceDeepfakeDataset(torch.utils.data.Dataset):
    def __init__(self, folders, n_frames=None, n_audio_reads=50027, train=True, device=None, cache_folder=None):
        self.n_frames = n_frames
        self.videos = []
        self.train = train
        self.device = device if device is not None else torch.device("cpu")
        self.cache_folder = cache_folder
        self.detector = MTCNN(device=device, post_process=False)

        # Load video paths
        for i in range(len(folders)):
            if train:
                with open('/content/output_balenced_train.json') as f:
                    videos = json.load(f)
                    videos = [(video, metadata) for (video, metadata) in videos.items()]
                    self.videos += videos
            else:
                self.videos += glob.glob(folders[i] + "/*.mp4")

        if self.cache_folder:
            os.makedirs(self.cache_folder, exist_ok=True)

    def __process_frame(self, frame, video_id, frame_idx):
        cache_path = os.path.join(self.cache_folder, f"{video_id}_frame{frame_idx}.pt") if self.cache_folder else None

        # Якщо файл з кешем існує, завантажуємо його
        if cache_path and os.path.exists(cache_path):
            return torch.load(cache_path)

        # Інакше обробляємо кадр
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        boxes, _ = self.detector.detect(frame, landmarks=False)

        if boxes is None:
            return None
        else:
            box = boxes[0]
            width = box[2] - box[0]
            height = box[3] - box[1]
            expand_x = width * 0.3 / 2
            expand_y = height * 0.3 / 2
            x1 = max(int(box[0] - expand_x), 0)
            y1 = max(int(box[1] - expand_y), 0)
            x2 = min(int(box[2] + expand_x), frame.shape[1])
            y2 = min(int(box[3] + expand_y), frame.shape[0])

            face = frame[y1:y2, x1:x2]
            face = cv2.resize(face, (224, 224))
            face = torch.from_numpy(face).permute(2, 0, 1).float() / 255.0

            # Зберігаємо оброблений кадр у кеш
            if cache_path:
                torch.save(face, cache_path)

            return face

    def __getitem__(self, n):
        if self.train:
            video, metadata = self.videos[n]
        else:
            video = self.videos[n]

        video_id = os.path.splitext(os.path.basename(video))[0]
        cap = cv2.VideoCapture(video)

        frames = []
        frame_idx = 0
        while len(frames) < self.n_frames:
            ret, frame = cap.read()
            if not ret:
                break

            processed_frame = self.__process_frame(frame, video_id, frame_idx)
            if processed_frame is not None:
                frames.append(processed_frame)
            frame_idx += 1

        cap.release()
        frames = torch.stack(frames).to(self.device)

        if self.train:
            label = 0.0
            if metadata['label'] == 'FAKE':
                label = 1.0
            return frames, torch.FloatTensor([label]).to(self.device)
        else:
            return frames

    def __len__(self):
        return len(self.videos)

# %%
def test_face_dataset():
    TRAIN_FOLDERS = ['/content/dfdc/']
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    dataset = FaceDeepfakeDataset(TRAIN_FOLDERS, n_frames=30, train=True, device=device)

    # Одержуємо перший батч
    for i, batch in enumerate(dataset):
        frames, label = batch
        print(f"Label: {label}")

        # Перевіряємо розмір кадрів
        if frames.size() != torch.Size([30, 3, 224, 224]):
            print(f"Unexpected frame size: {frames.size()}")

        # Візуалізуємо перші два кадри
        fig, axes = plt.subplots(1, 30, figsize=(30, 10))

        for j in range(30):
            ax = axes[j]
            frame = frames[j].cpu().permute(1, 2, 0).numpy()  # Перетворюємо з CHW в HWC і конвертуємо в NumPy
            ax.imshow(frame)  # Виводимо зображення
            ax.set_title(f"Frame {j+1}")
            ax.axis('off')

        plt.show()
        break  # Призупиняємо після першого батчу

test_face_dataset()
# Out:
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:79: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# Label: tensor([1.], device='cuda:0')

# %%
class FaceDeepfakeDatasetTest(torch.utils.data.Dataset):
    def __init__(self, folders, n_frames=None, n_audio_reads=50027, train=True, device=None, cache_folder=None):
        self.n_frames = n_frames
        self.videos = []
        self.train = train
        self.device = device if device is not None else torch.device("cpu")
        self.cache_folder = cache_folder
        self.detector = MTCNN(device=device, post_process=False)

        # Load video paths
        for i in range(len(folders)):
            if train:
                with open('/content/output_balenced_test.json') as f:
                    videos = json.load(f)
                    videos = [(video, metadata) for (video, metadata) in videos.items()]
                    self.videos += videos
            else:
                self.videos += glob.glob(folders[i] + "/*.mp4")

        if self.cache_folder:
            os.makedirs(self.cache_folder, exist_ok=True)

    def __process_frame(self, frame, video_id, frame_idx):
        cache_path = os.path.join(self.cache_folder, f"{video_id}_frame{frame_idx}.pt") if self.cache_folder else None

        # Якщо файл з кешем існує, завантажуємо його
        if cache_path and os.path.exists(cache_path):
            return torch.load(cache_path)

        # Інакше обробляємо кадр
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        boxes, _ = self.detector.detect(frame, landmarks=False)

        if boxes is None:
            return None
        else:
            box = boxes[0]
            width = box[2] - box[0]
            height = box[3] - box[1]
            expand_x = width * 0.3 / 2
            expand_y = height * 0.3 / 2
            x1 = max(int(box[0] - expand_x), 0)
            y1 = max(int(box[1] - expand_y), 0)
            x2 = min(int(box[2] + expand_x), frame.shape[1])
            y2 = min(int(box[3] + expand_y), frame.shape[0])

            face = frame[y1:y2, x1:x2]
            face = cv2.resize(face, (224, 224))
            face = torch.from_numpy(face).permute(2, 0, 1).float() / 255.0

            # Зберігаємо оброблений кадр у кеш
            if cache_path:
                torch.save(face, cache_path)

            return face

    def __getitem__(self, n):
        if self.train:
            video, metadata = self.videos[n]
        else:
            video = self.videos[n]

        video_id = os.path.splitext(os.path.basename(video))[0]
        cap = cv2.VideoCapture(video)

        frames = []
        frame_idx = 0
        while len(frames) < self.n_frames:
            ret, frame = cap.read()
            if not ret:
                break

            processed_frame = self.__process_frame(frame, video_id, frame_idx)
            if processed_frame is not None:
                frames.append(processed_frame)
            frame_idx += 1

        cap.release()
        frames = torch.stack(frames).to(self.device)

        if self.train:
            label = 0.0
            if metadata['label'] == 'FAKE':
                label = 1.0
            return frames, torch.FloatTensor([label]).to(self.device)
        else:
            return frames

    def __len__(self):
        return len(self.videos)

# %%
def test_face_dataset():
    TRAIN_FOLDERS = ['/content/test_videos']
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    dataset = FaceDeepfakeDatasetTest(TRAIN_FOLDERS, n_frames=30, train=True, device=device, cache_folder=None)

    # Одержуємо перший батч
    for i, batch in enumerate(dataset):
        frames, label = batch
        print(f"Label: {label}")

        # Перевіряємо розмір кадрів
        if frames.size() != torch.Size([30, 3, 224, 224]):
            print(f"Unexpected frame size: {frames.size()}")

        # Візуалізуємо перші два кадри
        fig, axes = plt.subplots(1, 30, figsize=(30, 10))

        for j in range(30):
            ax = axes[j]
            frame = frames[j].cpu().permute(1, 2, 0).numpy()  # Перетворюємо з CHW в HWC і конвертуємо в NumPy
            ax.imshow(frame)  # Виводимо зображення
            ax.set_title(f"Frame {j+1}")
            ax.axis('off')

        plt.show()
        break  # Призупиняємо після першого батчу

test_face_dataset()
# Out:
# Label: tensor([0.], device='cuda:0')

# %%
import torch
import torch.nn as nn
import math
from torch.nn import functional as F
import torchvision.models as models


class FaceClassifier(nn.Module):
    def __init__(self, n_linear_hidden=256, lstm_hidden_dim=128, num_lstm_layers=1):
        super(FaceClassifier, self).__init__()

        # Завантаження попередньо натренованої EfficientNet
        self.cnn = models.efficientnet_b0(pretrained=True)
        self.feature_extractor = nn.Sequential(*list(self.cnn.children())[:-1])  # Виключаємо шар класифікації

        for param in self.feature_extractor.parameters():
            param.requires_grad = False

        # Розмір виходу від feature extractor
        self.feature_output_size = 1280  # EfficientNet B7 дає 2560 ознак

        # LSTM для обробки послідовності ознак кожного кадру
        self.lstm = nn.LSTM(input_size=self.feature_output_size,
                            hidden_size=lstm_hidden_dim,
                            num_layers=num_lstm_layers,
                            batch_first=True,
                            bidirectional=True)

        # Повнозв'язні шари для класифікації
        self.fc1 = nn.Linear(2 * lstm_hidden_dim, n_linear_hidden)  # множимо на 2 через bidirectional LSTM
        self.fc2 = nn.Linear(n_linear_hidden, 1)

    def forward(self, vid_frames):
        # Витягання ознак для кожного кадру
        batch_size, num_frames, channels, height, width = vid_frames.shape
        vid_frames = vid_frames.view(batch_size * num_frames, channels, height, width)

        # Використовуємо фічерний екстрактор
        with torch.no_grad():
            vid_features = self.feature_extractor(vid_frames)

        # Переформатовуємо ознаки для LSTM
        vid_features = vid_features.view(batch_size, num_frames, -1)  # (batch_size, num_frames, feature_output_size)

        # Обробка послідовності кадрів через LSTM
        lstm_out, _ = self.lstm(vid_features)  # lstm_out: (batch_size, num_frames, 2 * lstm_hidden_dim)

        # Використання середнього значення по кадрам для об'єднання послідовності (можна також використовувати останній кадр або інші методи агрегації)
        lstm_out = torch.mean(lstm_out, dim=1)  # (batch_size, 2 * lstm_hidden_dim)

        # Класифікаційні шари
        x = torch.relu(self.fc1(lstm_out))
        x = self.fc2(x)

        return x

# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import datetime
import sys
import pandas as pd
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import torchvision
import gc


train_folders = ['/content/dfdc']
test_folders = ['/content/test_videos']

batch_size = int(8)
num_epochs = int(4)
n_frames = int(10)
lr = float(0.001)

TRAIN_FOLDERS = train_folders
TEST_FOLDERS = test_folders
print(f"all train folders: {train_folders}, {type(train_folders)}")
print(f"all test folders: {test_folders}, {type(test_folders)}")

gamma = 0.1
milestones = [6,12,18]

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = FaceClassifier()
#model.load_state_dict(torch.load('/content/drive/MyDrive/b7_faces_224_b0_lstm_celebav_1_classifier_30_small.pt', map_location=device))
model = model.to(device)
class_weights = {0: 0.6191950464396285, 1: 10.1230}
weights_tensor = torch.tensor([class_weights[0], 10.1230], dtype=torch.float32).to(device)

# Modify the loss function
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=gamma)

start_time = datetime.datetime.now()
print(f'start time: {str(start_time)}')
print(f'using device: {device}')

'''Splitting into Train and Validation'''
train_dataset = FaceDeepfakeDataset(TRAIN_FOLDERS,  n_frames=n_frames, n_audio_reads=576, device=device, cache_folder="face_encode_cache")
test_dataset = FaceDeepfakeDatasetTest(TEST_FOLDERS, n_frames=n_frames, n_audio_reads=576, device=device,  cache_folder="face_encode_cache")

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
print(len(train_loader))


'''Train_Loop'''
train_losses = []
val_losses = []
best_loss = np.inf
train_accuracies = []
val_accuracies = []
epoch_times = []


for epoch in range(num_epochs):
    epoch_start_time = time.time()
    epoch_t_loss = 0
    epoch_v_loss = 0
    t_count = 0
    t_count_wrong = 0
    train_labels_all = []
    train_preds_all = []

    model.train()
    torch.cuda.empty_cache()
    gc.collect()
    for i, batch in tqdm(enumerate(train_loader)):
        torch.cuda.empty_cache()
        gc.collect()
        # if i * batch_size >= epoch_size:
        #     break
        video_data, labels = batch
        video_data = video_data.to(device)
        #audio_data = audio_data.to(device)

        output = model(video_data)
        loss = criterion(output, labels)

        output = torch.sigmoid(output)
        output = output.round()

        n_wrong = (labels - output).abs().sum()
        t_count_wrong += n_wrong
        t_count += labels.shape[0]

        epoch_t_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_labels_all.extend(labels.cpu().detach().numpy())
        train_preds_all.extend(output.cpu().detach().numpy())

        #print('.', end='', flush=True)
        torch.cuda.empty_cache()
        gc.collect()

    # Перетворіть на numpy-масиви
    train_labels_all = np.array(train_labels_all).astype(int)
    train_preds_all = np.array(train_preds_all).astype(int)

    # Обчисліть та виведіть матрицю плутанини для тренувального набору
    conf_matrix_train = confusion_matrix(train_labels_all, train_preds_all)
    print(conf_matrix_train)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix (Train Set)')
    plt.show()

    # Виведіть класифікаційний звіт для тренувального набору
    print("Classification Report (Train Set):")
    print(classification_report(train_labels_all, train_preds_all, target_names=['Real', 'Fake']))

    all_labels = []
    all_preds = []

    model.eval()
    with torch.no_grad():
        v_count = 0
        v_count_wrong = 0
        for i, batch in enumerate(val_loader):
            # if i * batch_size >= epoch_size:
        #        break
            torch.cuda.empty_cache()
            gc.collect()
            video_data, labels = batch
            video_data = video_data.to(device)
            #audio_data = audio_data.to(device)
            # optimizer.zero_grad()
            output = model(video_data)
            loss = criterion(output, labels)

            output = torch.sigmoid(output)
            output = output.round()
            n_wrong = (labels - output).abs().sum()
            v_count_wrong += n_wrong
            v_count += labels.shape[0]

            epoch_v_loss += loss.item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(output.cpu().numpy())

            # loss.backward()
            # optimizer.step()
            print('.', end='', flush=True)
            torch.cuda.empty_cache()
            gc.collect()

    epoch_end_time = time.time()
    epoch_exec_time = epoch_end_time - epoch_start_time
    epoch_times.append(epoch_exec_time)
    train_losses.append(epoch_t_loss/len(train_loader))
    val_losses.append(epoch_t_loss/len(val_loader))

    t_count_right = t_count - t_count_wrong
    v_count_right = v_count - v_count_wrong
    t_accuracy = t_count_right / t_count
    v_accuracy = v_count_right / v_count

    train_accuracies.append(t_accuracy)
    val_accuracies.append(v_accuracy)

    print(f'\nepoch: {epoch}, train loss: {train_losses[-1]}, val loss: {val_losses[-1]}, executed in: {str(epoch_exec_time)}')
    print(f"train total: {t_count}, train correct: {t_count_right}, train incorrect: {t_count_wrong}, train accuracy: {t_accuracy}")
    print(f"valid total: {v_count}, valid correct: {v_count_right}, valid incorrect: {v_count_wrong}, valid accuracy: {v_accuracy}")
    all_labels = np.array(all_labels).astype(int)
    all_preds = np.array(all_preds).astype(int)
    # Обчислення та візуалізація матриці плутанини
    conf_matrix = confusion_matrix(all_labels, all_preds)
    #print(conf_matrix)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

    # Друк звіту про класифікацію
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=['Real', 'Fake']))

    scheduler.step()
    ### Saving model per best validation loss
    if best_loss > val_losses[-1]:
        best_loss = val_losses[-1]
        end_time = datetime.datetime.now()
        torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 1}_classifier_{n_frames}_small.pt')
    torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 1}_classifier_{n_frames}_small.pt')


end_time = datetime.datetime.now()
print(f"end time: {str(end_time)}")
exec_time = end_time - start_time
print(f"executed in: {str(exec_time)}")
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# all train folders: ['/content/dfdc'], <class 'list'>
# all test folders: ['/content/test_videos'], <class 'list'>
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 64.2MB/s]
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:79: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# start time: 2024-11-10 14:44:48.109613
# using device: cuda
# 503
# 503it [1:38:27, 11.74s/it]
# [[1211  799]
#  [ 579 1430]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.68      0.60      0.64      2010
#         Fake       0.64      0.71      0.67      2009
#
#     accuracy                           0.66      4019
#    macro avg       0.66      0.66      0.66      4019
# weighted avg       0.66      0.66      0.66      4019
#
# ..............................................................................................................................
# epoch: 0, train loss: 0.615542831317805, val loss: 2.4572860647052055, executed in: 7213.539307117462
# train total: 4019, train correct: 2641.0, train incorrect: 1378.0, train accuracy: 0.657128632068634
# valid total: 1005, valid correct: 700.0, valid incorrect: 305.0, valid accuracy: 0.6965174674987793
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.79      0.53      0.64       502
#         Fake       0.65      0.86      0.74       503
#
#     accuracy                           0.70      1005
#    macro avg       0.72      0.70      0.69      1005
# weighted avg       0.72      0.70      0.69      1005
# 0it [00:00, ?it/s]<ipython-input-16-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [16:47,  2.00s/it]
# [[1377  633]
#  [ 535 1474]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.72      0.69      0.70      2010
#         Fake       0.70      0.73      0.72      2009
#
#     accuracy                           0.71      4019
#    macro avg       0.71      0.71      0.71      4019
# weighted avg       0.71      0.71      0.71      4019
# <ipython-input-18-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 1, train loss: 0.5641638658511235, val loss: 2.252177972405676, executed in: 1261.3576426506042
# train total: 4019, train correct: 2851.0, train incorrect: 1168.0, train accuracy: 0.7093804478645325
# valid total: 1005, valid correct: 743.0, valid incorrect: 262.0, valid accuracy: 0.7393035292625427
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.76      0.69      0.73       502
#         Fake       0.72      0.79      0.75       503
#
#     accuracy                           0.74      1005
#    macro avg       0.74      0.74      0.74      1005
# weighted avg       0.74      0.74      0.74      1005
# 0it [00:00, ?it/s]<ipython-input-16-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [16:49,  2.01s/it]
# [[1449  561]
#  [ 519 1490]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.74      0.72      0.73      2010
#         Fake       0.73      0.74      0.73      2009
#
#     accuracy                           0.73      4019
#    macro avg       0.73      0.73      0.73      4019
# weighted avg       0.73      0.73      0.73      4019
# <ipython-input-18-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 2, train loss: 0.5227728654032436, val loss: 2.0869424706177107, executed in: 1260.949372291565
# train total: 4019, train correct: 2939.0, train incorrect: 1080.0, train accuracy: 0.7312763929367065
# valid total: 1005, valid correct: 771.0, valid incorrect: 234.0, valid accuracy: 0.7671642303466797
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.78      0.74      0.76       502
#         Fake       0.76      0.79      0.77       503
#
#     accuracy                           0.77      1005
#    macro avg       0.77      0.77      0.77      1005
# weighted avg       0.77      0.77      0.77      1005
# 0it [00:00, ?it/s]<ipython-input-16-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [17:07,  2.04s/it]
# [[1447  563]
#  [ 438 1571]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.77      0.72      0.74      2010
#         Fake       0.74      0.78      0.76      2009
#
#     accuracy                           0.75      4019
#    macro avg       0.75      0.75      0.75      4019
# weighted avg       0.75      0.75      0.75      4019
# <ipython-input-18-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 3, train loss: 0.4992137798376633, val loss: 1.9928931052249574, executed in: 1287.2172539234161
# train total: 4019, train correct: 3018.0, train incorrect: 1001.0, train accuracy: 0.750933051109314
# valid total: 1005, valid correct: 762.0, valid incorrect: 243.0, valid accuracy: 0.7582089900970459
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.75      0.78      0.76       502
#         Fake       0.77      0.73      0.75       503
#
#     accuracy                           0.76      1005
#    macro avg       0.76      0.76      0.76      1005
# weighted avg       0.76      0.76      0.76      1005
#
# end time: 2024-11-10 17:48:33.646445
# executed in: 3:03:45.536832
# Tesla T4
# Memory Usage:
# Allocated: 0.1 GB
# Cached:    0.2 GB
# <ipython-input-21-eafc851a2a6c>:218: FutureWarning: `torch.cuda.memory_cached` has been renamed to `torch.cuda.memory_reserved`
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')

# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import datetime
import sys
import pandas as pd
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import torchvision
import gc


train_folders = ['/content/dfdc']
test_folders = ['/content/test_videos']

batch_size = int(8)
num_epochs = int(5)
n_frames = int(10)
lr = float(0.001)

TRAIN_FOLDERS = train_folders
TEST_FOLDERS = test_folders
print(f"all train folders: {train_folders}, {type(train_folders)}")
print(f"all test folders: {test_folders}, {type(test_folders)}")

gamma = 0.1
milestones = [6,12,18]

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = FaceClassifier()
model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_4_classifier_10_small.pt', map_location=device))
model = model.to(device)
class_weights = {0: 0.6191950464396285, 1: 10.1230}
weights_tensor = torch.tensor([class_weights[0], 10.1230], dtype=torch.float32).to(device)

# Modify the loss function
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=gamma)

start_time = datetime.datetime.now()
print(f'start time: {str(start_time)}')
print(f'using device: {device}')

'''Splitting into Train and Validation'''
train_dataset = FaceDeepfakeDataset(TRAIN_FOLDERS,  n_frames=n_frames, n_audio_reads=576, device=device, cache_folder="face_encode_cache")
test_dataset = FaceDeepfakeDatasetTest(TEST_FOLDERS, n_frames=n_frames, n_audio_reads=576, device=device,  cache_folder="face_encode_cache")

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
print(len(train_loader))


'''Train_Loop'''
train_losses = []
val_losses = []
best_loss = np.inf
train_accuracies = []
val_accuracies = []
epoch_times = []


for epoch in range(num_epochs):
    epoch_start_time = time.time()
    epoch_t_loss = 0
    epoch_v_loss = 0
    t_count = 0
    t_count_wrong = 0
    train_labels_all = []
    train_preds_all = []

    model.train()
    torch.cuda.empty_cache()
    gc.collect()
    for i, batch in tqdm(enumerate(train_loader)):
        torch.cuda.empty_cache()
        gc.collect()
        # if i * batch_size >= epoch_size:
        #     break
        video_data, labels = batch
        video_data = video_data.to(device)
        #audio_data = audio_data.to(device)

        output = model(video_data)
        loss = criterion(output, labels)

        output = torch.sigmoid(output)
        output = output.round()

        n_wrong = (labels - output).abs().sum()
        t_count_wrong += n_wrong
        t_count += labels.shape[0]

        epoch_t_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_labels_all.extend(labels.cpu().detach().numpy())
        train_preds_all.extend(output.cpu().detach().numpy())

        #print('.', end='', flush=True)
        torch.cuda.empty_cache()
        gc.collect()

    # Перетворіть на numpy-масиви
    train_labels_all = np.array(train_labels_all).astype(int)
    train_preds_all = np.array(train_preds_all).astype(int)

    # Обчисліть та виведіть матрицю плутанини для тренувального набору
    conf_matrix_train = confusion_matrix(train_labels_all, train_preds_all)
    print(conf_matrix_train)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix (Train Set)')
    plt.show()

    # Виведіть класифікаційний звіт для тренувального набору
    print("Classification Report (Train Set):")
    print(classification_report(train_labels_all, train_preds_all, target_names=['Real', 'Fake']))

    all_labels = []
    all_preds = []

    model.eval()
    with torch.no_grad():
        v_count = 0
        v_count_wrong = 0
        for i, batch in enumerate(val_loader):
            # if i * batch_size >= epoch_size:
        #        break
            torch.cuda.empty_cache()
            gc.collect()
            video_data, labels = batch
            video_data = video_data.to(device)
            #audio_data = audio_data.to(device)
            # optimizer.zero_grad()
            output = model(video_data)
            loss = criterion(output, labels)

            output = torch.sigmoid(output)
            output = output.round()
            n_wrong = (labels - output).abs().sum()
            v_count_wrong += n_wrong
            v_count += labels.shape[0]

            epoch_v_loss += loss.item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(output.cpu().numpy())

            # loss.backward()
            # optimizer.step()
            print('.', end='', flush=True)
            torch.cuda.empty_cache()
            gc.collect()

    epoch_end_time = time.time()
    epoch_exec_time = epoch_end_time - epoch_start_time
    epoch_times.append(epoch_exec_time)
    train_losses.append(epoch_t_loss/len(train_loader))
    val_losses.append(epoch_t_loss/len(val_loader))

    t_count_right = t_count - t_count_wrong
    v_count_right = v_count - v_count_wrong
    t_accuracy = t_count_right / t_count
    v_accuracy = v_count_right / v_count

    train_accuracies.append(t_accuracy)
    val_accuracies.append(v_accuracy)

    print(f'\nepoch: {epoch + 4}, train loss: {train_losses[-1]}, val loss: {val_losses[-1]}, executed in: {str(epoch_exec_time)}')
    print(f"train total: {t_count}, train correct: {t_count_right}, train incorrect: {t_count_wrong}, train accuracy: {t_accuracy}")
    print(f"valid total: {v_count}, valid correct: {v_count_right}, valid incorrect: {v_count_wrong}, valid accuracy: {v_accuracy}")
    all_labels = np.array(all_labels).astype(int)
    all_preds = np.array(all_preds).astype(int)
    # Обчислення та візуалізація матриці плутанини
    conf_matrix = confusion_matrix(all_labels, all_preds)
    #print(conf_matrix)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

    # Друк звіту про класифікацію
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=['Real', 'Fake']))

    scheduler.step()
    ### Saving model per best validation loss
    if best_loss > val_losses[-1]:
        best_loss = val_losses[-1]
        end_time = datetime.datetime.now()
        torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 5}_classifier_{n_frames}_small.pt')
    torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 5}_classifier_{n_frames}_small.pt')


end_time = datetime.datetime.now()
print(f"end time: {str(end_time)}")
exec_time = end_time - start_time
print(f"executed in: {str(exec_time)}")
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# all train folders: ['/content/dfdc'], <class 'list'>
# all test folders: ['/content/test_videos'], <class 'list'>
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 134MB/s]
# <ipython-input-27-578a50b9e93a>:38: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_4_classifier_10_small.pt', map_location=device))
# start time: 2024-11-11 07:50:50.668710
# using device: cuda
# 503
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:79: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# 503it [1:38:29, 11.75s/it]
# [[1538  472]
#  [ 370 1639]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.81      0.77      0.79      2010
#         Fake       0.78      0.82      0.80      2009
#
#     accuracy                           0.79      4019
#    macro avg       0.79      0.79      0.79      4019
# weighted avg       0.79      0.79      0.79      4019
#
# ..............................................................................................................................
# epoch: 4, train loss: 0.442650418573061, val loss: 1.7670885757321404, executed in: 7197.352414369583
# train total: 4019, train correct: 3177.0, train incorrect: 842.0, train accuracy: 0.7904950976371765
# valid total: 1005, valid correct: 765.0, valid incorrect: 240.0, valid accuracy: 0.7611940503120422
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.80      0.70      0.75       502
#         Fake       0.73      0.82      0.78       503
#
#     accuracy                           0.76      1005
#    macro avg       0.77      0.76      0.76      1005
# weighted avg       0.77      0.76      0.76      1005
# 0it [00:00, ?it/s]<ipython-input-22-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [16:35,  1.98s/it]
# [[1551  459]
#  [ 365 1644]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.81      0.77      0.79      2010
#         Fake       0.78      0.82      0.80      2009
#
#     accuracy                           0.79      4019
#    macro avg       0.80      0.79      0.79      4019
# weighted avg       0.80      0.79      0.79      4019
# <ipython-input-24-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 5, train loss: 0.43217002301223234, val loss: 1.725250171231372, executed in: 1242.2664804458618
# train total: 4019, train correct: 3195.0, train incorrect: 824.0, train accuracy: 0.7949738502502441
# valid total: 1005, valid correct: 781.0, valid incorrect: 224.0, valid accuracy: 0.7771144509315491
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.79      0.76      0.77       502
#         Fake       0.77      0.80      0.78       503
#
#     accuracy                           0.78      1005
#    macro avg       0.78      0.78      0.78      1005
# weighted avg       0.78      0.78      0.78      1005
# 0it [00:00, ?it/s]<ipython-input-22-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [16:23,  1.96s/it]
# [[1571  439]
#  [ 307 1702]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.84      0.78      0.81      2010
#         Fake       0.79      0.85      0.82      2009
#
#     accuracy                           0.81      4019
#    macro avg       0.82      0.81      0.81      4019
# weighted avg       0.82      0.81      0.81      4019
# <ipython-input-24-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 6, train loss: 0.3978406614873921, val loss: 1.5882051803822081, executed in: 1227.8573207855225
# train total: 4019, train correct: 3273.0, train incorrect: 746.0, train accuracy: 0.8143816590309143
# valid total: 1005, valid correct: 746.0, valid incorrect: 259.0, valid accuracy: 0.7422885894775391
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.73      0.78      0.75       502
#         Fake       0.76      0.71      0.73       503
#
#     accuracy                           0.74      1005
#    macro avg       0.74      0.74      0.74      1005
# weighted avg       0.74      0.74      0.74      1005
# 0it [00:00, ?it/s]<ipython-input-22-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [16:29,  1.97s/it]
# [[1610  400]
#  [ 295 1714]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.85      0.80      0.82      2010
#         Fake       0.81      0.85      0.83      2009
#
#     accuracy                           0.83      4019
#    macro avg       0.83      0.83      0.83      4019
# weighted avg       0.83      0.83      0.83      4019
# <ipython-input-24-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 7, train loss: 0.377234547041638, val loss: 1.505944263190031, executed in: 1236.916374206543
# train total: 4019, train correct: 3324.0, train incorrect: 695.0, train accuracy: 0.8270713686943054
# valid total: 1005, valid correct: 776.0, valid incorrect: 229.0, valid accuracy: 0.772139310836792
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.81      0.72      0.76       502
#         Fake       0.74      0.83      0.78       503
#
#     accuracy                           0.77      1005
#    macro avg       0.78      0.77      0.77      1005
# weighted avg       0.78      0.77      0.77      1005
# 0it [00:00, ?it/s]<ipython-input-22-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [16:19,  1.95s/it]
# [[1641  369]
#  [ 277 1732]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.86      0.82      0.84      2010
#         Fake       0.82      0.86      0.84      2009
#
#     accuracy                           0.84      4019
#    macro avg       0.84      0.84      0.84      4019
# weighted avg       0.84      0.84      0.84      4019
# <ipython-input-24-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 8, train loss: 0.35783634302215594, val loss: 1.4285054011122575, executed in: 1222.9869678020477
# train total: 4019, train correct: 3373.0, train incorrect: 646.0, train accuracy: 0.8392634987831116
# valid total: 1005, valid correct: 787.0, valid incorrect: 218.0, valid accuracy: 0.7830846309661865
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.78      0.78      0.78       502
#         Fake       0.78      0.78      0.78       503
#
#     accuracy                           0.78      1005
#    macro avg       0.78      0.78      0.78      1005
# weighted avg       0.78      0.78      0.78      1005
#
# end time: 2024-11-11 11:13:01.402435
# executed in: 3:22:10.733725
# Tesla T4
# Memory Usage:
# Allocated: 0.1 GB
# Cached:    0.2 GB
# <ipython-input-27-578a50b9e93a>:218: FutureWarning: `torch.cuda.memory_cached` has been renamed to `torch.cuda.memory_reserved`
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')

# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import datetime
import sys
import pandas as pd
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import torchvision
import gc


train_folders = ['/content/dfdc']
test_folders = ['/content/test_videos']

batch_size = int(8)
num_epochs = int(5)
n_frames = int(10)
lr = float(0.001)

TRAIN_FOLDERS = train_folders
TEST_FOLDERS = test_folders
print(f"all train folders: {train_folders}, {type(train_folders)}")
print(f"all test folders: {test_folders}, {type(test_folders)}")

gamma = 0.1
milestones = [6,12,18]

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = FaceClassifier()
model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_9_classifier_10_small.pt', map_location=device))
model = model.to(device)
class_weights = {0: 0.6191950464396285, 1: 10.1230}
weights_tensor = torch.tensor([class_weights[0], 10.1230], dtype=torch.float32).to(device)

# Modify the loss function
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=gamma)

start_time = datetime.datetime.now()
print(f'start time: {str(start_time)}')
print(f'using device: {device}')

'''Splitting into Train and Validation'''
train_dataset = FaceDeepfakeDataset(TRAIN_FOLDERS,  n_frames=n_frames, n_audio_reads=576, device=device, cache_folder="face_encode_cache")
test_dataset = FaceDeepfakeDatasetTest(TEST_FOLDERS, n_frames=n_frames, n_audio_reads=576, device=device,  cache_folder="face_encode_cache")

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
print(len(train_loader))


'''Train_Loop'''
train_losses = []
val_losses = []
best_loss = np.inf
train_accuracies = []
val_accuracies = []
epoch_times = []


for epoch in range(num_epochs):
    epoch_start_time = time.time()
    epoch_t_loss = 0
    epoch_v_loss = 0
    t_count = 0
    t_count_wrong = 0
    train_labels_all = []
    train_preds_all = []

    model.train()
    torch.cuda.empty_cache()
    gc.collect()
    for i, batch in tqdm(enumerate(train_loader)):
        torch.cuda.empty_cache()
        gc.collect()
        # if i * batch_size >= epoch_size:
        #     break
        video_data, labels = batch
        video_data = video_data.to(device)
        #audio_data = audio_data.to(device)

        output = model(video_data)
        loss = criterion(output, labels)

        output = torch.sigmoid(output)
        output = output.round()

        n_wrong = (labels - output).abs().sum()
        t_count_wrong += n_wrong
        t_count += labels.shape[0]

        epoch_t_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_labels_all.extend(labels.cpu().detach().numpy())
        train_preds_all.extend(output.cpu().detach().numpy())

        #print('.', end='', flush=True)
        torch.cuda.empty_cache()
        gc.collect()

    # Перетворіть на numpy-масиви
    train_labels_all = np.array(train_labels_all).astype(int)
    train_preds_all = np.array(train_preds_all).astype(int)

    # Обчисліть та виведіть матрицю плутанини для тренувального набору
    conf_matrix_train = confusion_matrix(train_labels_all, train_preds_all)
    print(conf_matrix_train)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix (Train Set)')
    plt.show()

    # Виведіть класифікаційний звіт для тренувального набору
    print("Classification Report (Train Set):")
    print(classification_report(train_labels_all, train_preds_all, target_names=['Real', 'Fake']))

    all_labels = []
    all_preds = []

    model.eval()
    with torch.no_grad():
        v_count = 0
        v_count_wrong = 0
        for i, batch in enumerate(val_loader):
            # if i * batch_size >= epoch_size:
        #        break
            torch.cuda.empty_cache()
            gc.collect()
            video_data, labels = batch
            video_data = video_data.to(device)
            #audio_data = audio_data.to(device)
            # optimizer.zero_grad()
            output = model(video_data)
            loss = criterion(output, labels)

            output = torch.sigmoid(output)
            output = output.round()
            n_wrong = (labels - output).abs().sum()
            v_count_wrong += n_wrong
            v_count += labels.shape[0]

            epoch_v_loss += loss.item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(output.cpu().numpy())

            # loss.backward()
            # optimizer.step()
            print('.', end='', flush=True)
            torch.cuda.empty_cache()
            gc.collect()

    epoch_end_time = time.time()
    epoch_exec_time = epoch_end_time - epoch_start_time
    epoch_times.append(epoch_exec_time)
    train_losses.append(epoch_t_loss/len(train_loader))
    val_losses.append(epoch_t_loss/len(val_loader))

    t_count_right = t_count - t_count_wrong
    v_count_right = v_count - v_count_wrong
    t_accuracy = t_count_right / t_count
    v_accuracy = v_count_right / v_count

    train_accuracies.append(t_accuracy)
    val_accuracies.append(v_accuracy)

    print(f'\nepoch: {epoch + 9}, train loss: {train_losses[-1]}, val loss: {val_losses[-1]}, executed in: {str(epoch_exec_time)}')
    print(f"train total: {t_count}, train correct: {t_count_right}, train incorrect: {t_count_wrong}, train accuracy: {t_accuracy}")
    print(f"valid total: {v_count}, valid correct: {v_count_right}, valid incorrect: {v_count_wrong}, valid accuracy: {v_accuracy}")
    all_labels = np.array(all_labels).astype(int)
    all_preds = np.array(all_preds).astype(int)
    # Обчислення та візуалізація матриці плутанини
    conf_matrix = confusion_matrix(all_labels, all_preds)
    #print(conf_matrix)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

    # Друк звіту про класифікацію
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=['Real', 'Fake']))

    scheduler.step()
    ### Saving model per best validation loss
    if best_loss > val_losses[-1]:
        best_loss = val_losses[-1]
        end_time = datetime.datetime.now()
        torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 9}_classifier_{n_frames}_small.pt')
    torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 9}_classifier_{n_frames}_small.pt')


end_time = datetime.datetime.now()
print(f"end time: {str(end_time)}")
exec_time = end_time - start_time
print(f"executed in: {str(exec_time)}")
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# all train folders: ['/content/dfdc'], <class 'list'>
# all test folders: ['/content/test_videos'], <class 'list'>
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 128MB/s]
# <ipython-input-22-af8ecd387bc9>:38: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_9_classifier_10_small.pt', map_location=device))
# start time: 2024-11-11 11:50:19.957663
# using device: cuda
# 503
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:79: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# 503it [1:40:36, 12.00s/it]
# [[1662  348]
#  [ 241 1768]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.87      0.83      0.85      2010
#         Fake       0.84      0.88      0.86      2009
#
#     accuracy                           0.85      4019
#    macro avg       0.85      0.85      0.85      4019
# weighted avg       0.85      0.85      0.85      4019
#
# ..............................................................................................................................
# epoch: 9, train loss: 0.3255711074688918, val loss: 1.2997005321972428, executed in: 7353.806949138641
# train total: 4019, train correct: 3430.0, train incorrect: 589.0, train accuracy: 0.8534461259841919
# valid total: 1005, valid correct: 780.0, valid incorrect: 225.0, valid accuracy: 0.7761194109916687
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.75      0.82      0.79       502
#         Fake       0.80      0.73      0.77       503
#
#     accuracy                           0.78      1005
#    macro avg       0.78      0.78      0.78      1005
# weighted avg       0.78      0.78      0.78      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [16:41,  1.99s/it]
# [[1675  335]
#  [ 258 1751]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.87      0.83      0.85      2010
#         Fake       0.84      0.87      0.86      2009
#
#     accuracy                           0.85      4019
#    macro avg       0.85      0.85      0.85      4019
# weighted avg       0.85      0.85      0.85      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 10, train loss: 0.31575217379801435, val loss: 1.2605027255587398, executed in: 1247.182631969452
# train total: 4019, train correct: 3426.0, train incorrect: 593.0, train accuracy: 0.8524508476257324
# valid total: 1005, valid correct: 767.0, valid incorrect: 238.0, valid accuracy: 0.763184130191803
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.72      0.86      0.78       502
#         Fake       0.82      0.67      0.74       503
#
#     accuracy                           0.76      1005
#    macro avg       0.77      0.76      0.76      1005
# weighted avg       0.77      0.76      0.76      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [16:31,  1.97s/it]
# [[1706  304]
#  [ 232 1777]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.88      0.85      0.86      2010
#         Fake       0.85      0.88      0.87      2009
#
#     accuracy                           0.87      4019
#    macro avg       0.87      0.87      0.87      4019
# weighted avg       0.87      0.87      0.87      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 11, train loss: 0.2982346173338814, val loss: 1.190571527928114, executed in: 1237.21608877182
# train total: 4019, train correct: 3483.0, train incorrect: 536.0, train accuracy: 0.8666334748268127
# valid total: 1005, valid correct: 808.0, valid incorrect: 197.0, valid accuracy: 0.8039801120758057
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.83      0.77      0.80       502
#         Fake       0.79      0.84      0.81       503
#
#     accuracy                           0.80      1005
#    macro avg       0.81      0.80      0.80      1005
# weighted avg       0.81      0.80      0.80      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [16:35,  1.98s/it]
# [[1721  289]
#  [ 229 1780]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.88      0.86      0.87      2010
#         Fake       0.86      0.89      0.87      2009
#
#     accuracy                           0.87      4019
#    macro avg       0.87      0.87      0.87      4019
# weighted avg       0.87      0.87      0.87      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 12, train loss: 0.293703449297526, val loss: 1.1724828174337745, executed in: 1249.1223363876343
# train total: 4019, train correct: 3501.0, train incorrect: 518.0, train accuracy: 0.8711121678352356
# valid total: 1005, valid correct: 774.0, valid incorrect: 231.0, valid accuracy: 0.770149290561676
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.76      0.80      0.78       502
#         Fake       0.79      0.74      0.76       503
#
#     accuracy                           0.77      1005
#    macro avg       0.77      0.77      0.77      1005
# weighted avg       0.77      0.77      0.77      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [16:38,  1.98s/it]
# [[1733  277]
#  [ 230 1779]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.88      0.86      0.87      2010
#         Fake       0.87      0.89      0.88      2009
#
#     accuracy                           0.87      4019
#    macro avg       0.87      0.87      0.87      4019
# weighted avg       0.87      0.87      0.87      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 13, train loss: 0.28410333135048627, val loss: 1.1341585370578937, executed in: 1248.3776185512543
# train total: 4019, train correct: 3512.0, train incorrect: 507.0, train accuracy: 0.8738492131233215
# valid total: 1005, valid correct: 793.0, valid incorrect: 212.0, valid accuracy: 0.7890547513961792
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.79      0.79      0.79       502
#         Fake       0.79      0.79      0.79       503
#
#     accuracy                           0.79      1005
#    macro avg       0.79      0.79      0.79      1005
# weighted avg       0.79      0.79      0.79      1005
#
# end time: 2024-11-11 15:15:58.672225
# executed in: 3:25:38.714562
# Tesla T4
# Memory Usage:
# Allocated: 0.1 GB
# Cached:    0.2 GB
# <ipython-input-22-af8ecd387bc9>:218: FutureWarning: `torch.cuda.memory_cached` has been renamed to `torch.cuda.memory_reserved`
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')

# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import datetime
import sys
import pandas as pd
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import torchvision
import gc


train_folders = ['/content/dfdc']
test_folders = ['/content/test_videos']

batch_size = int(8)
num_epochs = int(3)
n_frames = int(10)
lr = float(0.001)

TRAIN_FOLDERS = train_folders
TEST_FOLDERS = test_folders
print(f"all train folders: {train_folders}, {type(train_folders)}")
print(f"all test folders: {test_folders}, {type(test_folders)}")

gamma = 0.1
milestones = [6,12,18]

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = FaceClassifier()
model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_13_classifier_10_small.pt', map_location=device))
model = model.to(device)
class_weights = {0: 0.6191950464396285, 1: 10.1230}
weights_tensor = torch.tensor([class_weights[0], 10.1230], dtype=torch.float32).to(device)

# Modify the loss function
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=gamma)

start_time = datetime.datetime.now()
print(f'start time: {str(start_time)}')
print(f'using device: {device}')

'''Splitting into Train and Validation'''
train_dataset = FaceDeepfakeDataset(TRAIN_FOLDERS,  n_frames=n_frames, n_audio_reads=576, device=device, cache_folder="face_encode_cache")
test_dataset = FaceDeepfakeDatasetTest(TEST_FOLDERS, n_frames=n_frames, n_audio_reads=576, device=device,  cache_folder="face_encode_cache")

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
print(len(train_loader))


'''Train_Loop'''
train_losses = []
val_losses = []
best_loss = np.inf
train_accuracies = []
val_accuracies = []
epoch_times = []


for epoch in range(num_epochs):
    epoch_start_time = time.time()
    epoch_t_loss = 0
    epoch_v_loss = 0
    t_count = 0
    t_count_wrong = 0
    train_labels_all = []
    train_preds_all = []

    model.train()
    torch.cuda.empty_cache()
    gc.collect()
    for i, batch in tqdm(enumerate(train_loader)):
        torch.cuda.empty_cache()
        gc.collect()
        # if i * batch_size >= epoch_size:
        #     break
        video_data, labels = batch
        video_data = video_data.to(device)
        #audio_data = audio_data.to(device)

        output = model(video_data)
        loss = criterion(output, labels)

        output = torch.sigmoid(output)
        output = output.round()

        n_wrong = (labels - output).abs().sum()
        t_count_wrong += n_wrong
        t_count += labels.shape[0]

        epoch_t_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_labels_all.extend(labels.cpu().detach().numpy())
        train_preds_all.extend(output.cpu().detach().numpy())

        #print('.', end='', flush=True)
        torch.cuda.empty_cache()
        gc.collect()

    # Перетворіть на numpy-масиви
    train_labels_all = np.array(train_labels_all).astype(int)
    train_preds_all = np.array(train_preds_all).astype(int)

    # Обчисліть та виведіть матрицю плутанини для тренувального набору
    conf_matrix_train = confusion_matrix(train_labels_all, train_preds_all)
    print(conf_matrix_train)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix (Train Set)')
    plt.show()

    # Виведіть класифікаційний звіт для тренувального набору
    print("Classification Report (Train Set):")
    print(classification_report(train_labels_all, train_preds_all, target_names=['Real', 'Fake']))

    all_labels = []
    all_preds = []

    model.eval()
    with torch.no_grad():
        v_count = 0
        v_count_wrong = 0
        for i, batch in enumerate(val_loader):
            # if i * batch_size >= epoch_size:
        #        break
            torch.cuda.empty_cache()
            gc.collect()
            video_data, labels = batch
            video_data = video_data.to(device)
            #audio_data = audio_data.to(device)
            # optimizer.zero_grad()
            output = model(video_data)
            loss = criterion(output, labels)

            output = torch.sigmoid(output)
            output = output.round()
            n_wrong = (labels - output).abs().sum()
            v_count_wrong += n_wrong
            v_count += labels.shape[0]

            epoch_v_loss += loss.item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(output.cpu().numpy())

            # loss.backward()
            # optimizer.step()
            print('.', end='', flush=True)
            torch.cuda.empty_cache()
            gc.collect()

    epoch_end_time = time.time()
    epoch_exec_time = epoch_end_time - epoch_start_time
    epoch_times.append(epoch_exec_time)
    train_losses.append(epoch_t_loss/len(train_loader))
    val_losses.append(epoch_t_loss/len(val_loader))

    t_count_right = t_count - t_count_wrong
    v_count_right = v_count - v_count_wrong
    t_accuracy = t_count_right / t_count
    v_accuracy = v_count_right / v_count

    train_accuracies.append(t_accuracy)
    val_accuracies.append(v_accuracy)

    print(f'\nepoch: {epoch + 13}, train loss: {train_losses[-1]}, val loss: {val_losses[-1]}, executed in: {str(epoch_exec_time)}')
    print(f"train total: {t_count}, train correct: {t_count_right}, train incorrect: {t_count_wrong}, train accuracy: {t_accuracy}")
    print(f"valid total: {v_count}, valid correct: {v_count_right}, valid incorrect: {v_count_wrong}, valid accuracy: {v_accuracy}")
    all_labels = np.array(all_labels).astype(int)
    all_preds = np.array(all_preds).astype(int)
    # Обчислення та візуалізація матриці плутанини
    conf_matrix = confusion_matrix(all_labels, all_preds)
    #print(conf_matrix)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

    # Друк звіту про класифікацію
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=['Real', 'Fake']))

    scheduler.step()
    ### Saving model per best validation loss
    if best_loss > val_losses[-1]:
        best_loss = val_losses[-1]
        end_time = datetime.datetime.now()
        torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 13}_classifier_{n_frames}_small.pt')
    torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 13}_classifier_{n_frames}_small.pt')


end_time = datetime.datetime.now()
print(f"end time: {str(end_time)}")
exec_time = end_time - start_time
print(f"executed in: {str(exec_time)}")
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# all train folders: ['/content/dfdc'], <class 'list'>
# all test folders: ['/content/test_videos'], <class 'list'>
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 127MB/s]
# <ipython-input-22-7d305fd59426>:38: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_13_classifier_10_small.pt', map_location=device))
# start time: 2024-11-11 15:51:19.625154
# using device: cuda
# 503
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:79: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# 503it [1:41:17, 12.08s/it]
# [[1740  270]
#  [ 200 1809]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.90      0.87      0.88      2010
#         Fake       0.87      0.90      0.89      2009
#
#     accuracy                           0.88      4019
#    macro avg       0.88      0.88      0.88      4019
# weighted avg       0.88      0.88      0.88      4019
#
# ..............................................................................................................................
# epoch: 13, train loss: 0.27486529755989314, val loss: 1.0972797196240178, executed in: 7403.324685573578
# train total: 4019, train correct: 3549.0, train incorrect: 470.0, train accuracy: 0.8830554485321045
# valid total: 1005, valid correct: 780.0, valid incorrect: 225.0, valid accuracy: 0.7761194109916687
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.76      0.80      0.78       502
#         Fake       0.79      0.75      0.77       503
#
#     accuracy                           0.78      1005
#    macro avg       0.78      0.78      0.78      1005
# weighted avg       0.78      0.78      0.78      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [17:04,  2.04s/it]
# [[1768  242]
#  [ 192 1817]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.90      0.88      0.89      2010
#         Fake       0.88      0.90      0.89      2009
#
#     accuracy                           0.89      4019
#    macro avg       0.89      0.89      0.89      4019
# weighted avg       0.89      0.89      0.89      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 14, train loss: 0.24898171390242, val loss: 0.9939508102612481, executed in: 1276.7914135456085
# train total: 4019, train correct: 3585.0, train incorrect: 434.0, train accuracy: 0.892012894153595
# valid total: 1005, valid correct: 771.0, valid incorrect: 234.0, valid accuracy: 0.7671642303466797
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.75      0.81      0.78       502
#         Fake       0.79      0.73      0.76       503
#
#     accuracy                           0.77      1005
#    macro avg       0.77      0.77      0.77      1005
# weighted avg       0.77      0.77      0.77      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 242it [07:53,  1.94s/it]

# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import datetime
import sys
import pandas as pd
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import torchvision
import gc


train_folders = ['/content/dfdc']
test_folders = ['/content/test_videos']

batch_size = int(8)
num_epochs = int(3)
n_frames = int(10)
lr = float(0.001)

TRAIN_FOLDERS = train_folders
TEST_FOLDERS = test_folders
print(f"all train folders: {train_folders}, {type(train_folders)}")
print(f"all test folders: {test_folders}, {type(test_folders)}")

gamma = 0.1
milestones = [6,12,18]

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = FaceClassifier()
model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_14_classifier_10_small.pt', map_location=device))
model = model.to(device)
class_weights = {0: 0.6191950464396285, 1: 10.1230}
weights_tensor = torch.tensor([class_weights[0], 10.1230], dtype=torch.float32).to(device)

# Modify the loss function
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=gamma)

start_time = datetime.datetime.now()
print(f'start time: {str(start_time)}')
print(f'using device: {device}')

'''Splitting into Train and Validation'''
train_dataset = FaceDeepfakeDataset(TRAIN_FOLDERS,  n_frames=n_frames, n_audio_reads=576, device=device, cache_folder="face_encode_cache")
test_dataset = FaceDeepfakeDatasetTest(TEST_FOLDERS, n_frames=n_frames, n_audio_reads=576, device=device,  cache_folder="face_encode_cache")

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
print(len(train_loader))


'''Train_Loop'''
train_losses = []
val_losses = []
best_loss = np.inf
train_accuracies = []
val_accuracies = []
epoch_times = []


for epoch in range(num_epochs):
    epoch_start_time = time.time()
    epoch_t_loss = 0
    epoch_v_loss = 0
    t_count = 0
    t_count_wrong = 0
    train_labels_all = []
    train_preds_all = []

    model.train()
    torch.cuda.empty_cache()
    gc.collect()
    for i, batch in tqdm(enumerate(train_loader)):
        torch.cuda.empty_cache()
        gc.collect()
        # if i * batch_size >= epoch_size:
        #     break
        video_data, labels = batch
        video_data = video_data.to(device)
        #audio_data = audio_data.to(device)

        output = model(video_data)
        loss = criterion(output, labels)

        output = torch.sigmoid(output)
        output = output.round()

        n_wrong = (labels - output).abs().sum()
        t_count_wrong += n_wrong
        t_count += labels.shape[0]

        epoch_t_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_labels_all.extend(labels.cpu().detach().numpy())
        train_preds_all.extend(output.cpu().detach().numpy())

        #print('.', end='', flush=True)
        torch.cuda.empty_cache()
        gc.collect()

    # Перетворіть на numpy-масиви
    train_labels_all = np.array(train_labels_all).astype(int)
    train_preds_all = np.array(train_preds_all).astype(int)

    # Обчисліть та виведіть матрицю плутанини для тренувального набору
    conf_matrix_train = confusion_matrix(train_labels_all, train_preds_all)
    print(conf_matrix_train)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix (Train Set)')
    plt.show()

    # Виведіть класифікаційний звіт для тренувального набору
    print("Classification Report (Train Set):")
    print(classification_report(train_labels_all, train_preds_all, target_names=['Real', 'Fake']))

    all_labels = []
    all_preds = []

    model.eval()
    with torch.no_grad():
        v_count = 0
        v_count_wrong = 0
        for i, batch in enumerate(val_loader):
            # if i * batch_size >= epoch_size:
        #        break
            torch.cuda.empty_cache()
            gc.collect()
            video_data, labels = batch
            video_data = video_data.to(device)
            #audio_data = audio_data.to(device)
            # optimizer.zero_grad()
            output = model(video_data)
            loss = criterion(output, labels)

            output = torch.sigmoid(output)
            output = output.round()
            n_wrong = (labels - output).abs().sum()
            v_count_wrong += n_wrong
            v_count += labels.shape[0]

            epoch_v_loss += loss.item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(output.cpu().numpy())

            # loss.backward()
            # optimizer.step()
            print('.', end='', flush=True)
            torch.cuda.empty_cache()
            gc.collect()

    epoch_end_time = time.time()
    epoch_exec_time = epoch_end_time - epoch_start_time
    epoch_times.append(epoch_exec_time)
    train_losses.append(epoch_t_loss/len(train_loader))
    val_losses.append(epoch_t_loss/len(val_loader))

    t_count_right = t_count - t_count_wrong
    v_count_right = v_count - v_count_wrong
    t_accuracy = t_count_right / t_count
    v_accuracy = v_count_right / v_count

    train_accuracies.append(t_accuracy)
    val_accuracies.append(v_accuracy)

    print(f'\nepoch: {epoch + 15}, train loss: {train_losses[-1]}, val loss: {val_losses[-1]}, executed in: {str(epoch_exec_time)}')
    print(f"train total: {t_count}, train correct: {t_count_right}, train incorrect: {t_count_wrong}, train accuracy: {t_accuracy}")
    print(f"valid total: {v_count}, valid correct: {v_count_right}, valid incorrect: {v_count_wrong}, valid accuracy: {v_accuracy}")
    all_labels = np.array(all_labels).astype(int)
    all_preds = np.array(all_preds).astype(int)
    # Обчислення та візуалізація матриці плутанини
    conf_matrix = confusion_matrix(all_labels, all_preds)
    #print(conf_matrix)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

    # Друк звіту про класифікацію
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=['Real', 'Fake']))

    scheduler.step()
    ### Saving model per best validation loss
    if best_loss > val_losses[-1]:
        best_loss = val_losses[-1]
        end_time = datetime.datetime.now()
        torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 15}_classifier_{n_frames}_small.pt')
    torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 15}_classifier_{n_frames}_small.pt')


end_time = datetime.datetime.now()
print(f"end time: {str(end_time)}")
exec_time = end_time - start_time
print(f"executed in: {str(exec_time)}")
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# all train folders: ['/content/dfdc'], <class 'list'>
# all test folders: ['/content/test_videos'], <class 'list'>
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 134MB/s]
# <ipython-input-22-a88009b20f36>:38: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_14_classifier_10_small.pt', map_location=device))
# start time: 2024-11-11 19:13:55.042082
# using device: cuda
# 503
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:79: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# 503it [1:37:55, 11.68s/it]
# [[1779  231]
#  [ 185 1824]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.91      0.89      0.90      2010
#         Fake       0.89      0.91      0.90      2009
#
#     accuracy                           0.90      4019
#    macro avg       0.90      0.90      0.90      4019
# weighted avg       0.90      0.90      0.90      4019
#
# ..............................................................................................................................
# epoch: 15, train loss: 0.244213942514277, val loss: 0.9749175641641376, executed in: 7180.9282784461975
# train total: 4019, train correct: 3603.0, train incorrect: 416.0, train accuracy: 0.8964916467666626
# valid total: 1005, valid correct: 781.0, valid incorrect: 224.0, valid accuracy: 0.7771144509315491
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.76      0.80      0.78       502
#         Fake       0.79      0.75      0.77       503
#
#     accuracy                           0.78      1005
#    macro avg       0.78      0.78      0.78      1005
# weighted avg       0.78      0.78      0.78      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [16:42,  1.99s/it]
# [[1798  212]
#  [ 191 1818]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.90      0.89      0.90      2010
#         Fake       0.90      0.90      0.90      2009
#
#     accuracy                           0.90      4019
#    macro avg       0.90      0.90      0.90      4019
# weighted avg       0.90      0.90      0.90      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 16, train loss: 0.23080139413288986, val loss: 0.9213738194352666, executed in: 1253.5397243499756
# train total: 4019, train correct: 3616.0, train incorrect: 403.0, train accuracy: 0.8997262716293335
# valid total: 1005, valid correct: 773.0, valid incorrect: 232.0, valid accuracy: 0.7691542506217957
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.74      0.83      0.78       502
#         Fake       0.81      0.71      0.75       503
#
#     accuracy                           0.77      1005
#    macro avg       0.77      0.77      0.77      1005
# weighted avg       0.77      0.77      0.77      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [17:07,  2.04s/it]
# [[1808  202]
#  [ 173 1836]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.91      0.90      0.91      2010
#         Fake       0.90      0.91      0.91      2009
#
#     accuracy                           0.91      4019
#    macro avg       0.91      0.91      0.91      4019
# weighted avg       0.91      0.91      0.91      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 17, train loss: 0.22970554756952327, val loss: 0.9169991303767476, executed in: 1277.0533514022827
# train total: 4019, train correct: 3644.0, train incorrect: 375.0, train accuracy: 0.906693160533905
# valid total: 1005, valid correct: 787.0, valid incorrect: 218.0, valid accuracy: 0.7830846309661865
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.78      0.78      0.78       502
#         Fake       0.78      0.78      0.78       503
#
#     accuracy                           0.78      1005
#    macro avg       0.78      0.78      0.78      1005
# weighted avg       0.78      0.78      0.78      1005
#
# end time: 2024-11-11 21:55:48.375356
# executed in: 2:41:53.333274
# Tesla T4
# Memory Usage:
# Allocated: 0.1 GB
# Cached:    0.2 GB
# <ipython-input-22-a88009b20f36>:218: FutureWarning: `torch.cuda.memory_cached` has been renamed to `torch.cuda.memory_reserved`
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')

# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import datetime
import sys
import pandas as pd
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import torchvision
import gc


train_folders = ['/content/dfdc']
test_folders = ['/content/test_videos']

batch_size = int(8)
num_epochs = int(5)
n_frames = int(10)
lr = float(0.001)

TRAIN_FOLDERS = train_folders
TEST_FOLDERS = test_folders
print(f"all train folders: {train_folders}, {type(train_folders)}")
print(f"all test folders: {test_folders}, {type(test_folders)}")

gamma = 0.1
milestones = [6,12,18]

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = FaceClassifier()
model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_17_classifier_10_small.pt', map_location=device))
model = model.to(device)
class_weights = {0: 0.6191950464396285, 1: 10.1230}
weights_tensor = torch.tensor([class_weights[0], 10.1230], dtype=torch.float32).to(device)

# Modify the loss function
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=gamma)

start_time = datetime.datetime.now()
print(f'start time: {str(start_time)}')
print(f'using device: {device}')

'''Splitting into Train and Validation'''
train_dataset = FaceDeepfakeDataset(TRAIN_FOLDERS,  n_frames=n_frames, n_audio_reads=576, device=device, cache_folder="face_encode_cache")
test_dataset = FaceDeepfakeDatasetTest(TEST_FOLDERS, n_frames=n_frames, n_audio_reads=576, device=device,  cache_folder="face_encode_cache")

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
print(len(train_loader))


'''Train_Loop'''
train_losses = []
val_losses = []
best_loss = np.inf
train_accuracies = []
val_accuracies = []
epoch_times = []


for epoch in range(num_epochs):
    epoch_start_time = time.time()
    epoch_t_loss = 0
    epoch_v_loss = 0
    t_count = 0
    t_count_wrong = 0
    train_labels_all = []
    train_preds_all = []

    model.train()
    torch.cuda.empty_cache()
    gc.collect()
    for i, batch in tqdm(enumerate(train_loader)):
        torch.cuda.empty_cache()
        gc.collect()
        # if i * batch_size >= epoch_size:
        #     break
        video_data, labels = batch
        video_data = video_data.to(device)
        #audio_data = audio_data.to(device)

        output = model(video_data)
        loss = criterion(output, labels)

        output = torch.sigmoid(output)
        output = output.round()

        n_wrong = (labels - output).abs().sum()
        t_count_wrong += n_wrong
        t_count += labels.shape[0]

        epoch_t_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_labels_all.extend(labels.cpu().detach().numpy())
        train_preds_all.extend(output.cpu().detach().numpy())

        #print('.', end='', flush=True)
        torch.cuda.empty_cache()
        gc.collect()

    # Перетворіть на numpy-масиви
    train_labels_all = np.array(train_labels_all).astype(int)
    train_preds_all = np.array(train_preds_all).astype(int)

    # Обчисліть та виведіть матрицю плутанини для тренувального набору
    conf_matrix_train = confusion_matrix(train_labels_all, train_preds_all)
    print(conf_matrix_train)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix (Train Set)')
    plt.show()

    # Виведіть класифікаційний звіт для тренувального набору
    print("Classification Report (Train Set):")
    print(classification_report(train_labels_all, train_preds_all, target_names=['Real', 'Fake']))

    all_labels = []
    all_preds = []

    model.eval()
    with torch.no_grad():
        v_count = 0
        v_count_wrong = 0
        for i, batch in enumerate(val_loader):
            # if i * batch_size >= epoch_size:
        #        break
            torch.cuda.empty_cache()
            gc.collect()
            video_data, labels = batch
            video_data = video_data.to(device)
            #audio_data = audio_data.to(device)
            # optimizer.zero_grad()
            output = model(video_data)
            loss = criterion(output, labels)

            output = torch.sigmoid(output)
            output = output.round()
            n_wrong = (labels - output).abs().sum()
            v_count_wrong += n_wrong
            v_count += labels.shape[0]

            epoch_v_loss += loss.item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(output.cpu().numpy())

            # loss.backward()
            # optimizer.step()
            print('.', end='', flush=True)
            torch.cuda.empty_cache()
            gc.collect()

    epoch_end_time = time.time()
    epoch_exec_time = epoch_end_time - epoch_start_time
    epoch_times.append(epoch_exec_time)
    train_losses.append(epoch_t_loss/len(train_loader))
    val_losses.append(epoch_t_loss/len(val_loader))

    t_count_right = t_count - t_count_wrong
    v_count_right = v_count - v_count_wrong
    t_accuracy = t_count_right / t_count
    v_accuracy = v_count_right / v_count

    train_accuracies.append(t_accuracy)
    val_accuracies.append(v_accuracy)

    print(f'\nepoch: {epoch + 16}, train loss: {train_losses[-1]}, val loss: {val_losses[-1]}, executed in: {str(epoch_exec_time)}')
    print(f"train total: {t_count}, train correct: {t_count_right}, train incorrect: {t_count_wrong}, train accuracy: {t_accuracy}")
    print(f"valid total: {v_count}, valid correct: {v_count_right}, valid incorrect: {v_count_wrong}, valid accuracy: {v_accuracy}")
    all_labels = np.array(all_labels).astype(int)
    all_preds = np.array(all_preds).astype(int)
    # Обчислення та візуалізація матриці плутанини
    conf_matrix = confusion_matrix(all_labels, all_preds)
    #print(conf_matrix)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

    # Друк звіту про класифікацію
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=['Real', 'Fake']))

    scheduler.step()
    ### Saving model per best validation loss
    if best_loss > val_losses[-1]:
        best_loss = val_losses[-1]
        end_time = datetime.datetime.now()
        torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 17}_classifier_{n_frames}_small.pt')
    torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 17}_classifier_{n_frames}_small.pt')


end_time = datetime.datetime.now()
print(f"end time: {str(end_time)}")
exec_time = end_time - start_time
print(f"executed in: {str(exec_time)}")
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# all train folders: ['/content/dfdc'], <class 'list'>
# all test folders: ['/content/test_videos'], <class 'list'>
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 146MB/s]
# <ipython-input-22-d6c71fc491a8>:38: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_17_classifier_10_small.pt', map_location=device))
# start time: 2024-11-12 08:58:59.089479
# using device: cuda
# 503
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:79: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# 503it [1:43:30, 12.35s/it]
# [[1800  210]
#  [ 168 1841]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.91      0.90      0.90      2010
#         Fake       0.90      0.92      0.91      2009
#
#     accuracy                           0.91      4019
#    macro avg       0.91      0.91      0.91      4019
# weighted avg       0.91      0.91      0.91      4019
#
# ..............................................................................................................................
# epoch: 16, train loss: 0.2305048958756674, val loss: 0.9201901795671484, executed in: 7564.532880306244
# train total: 4019, train correct: 3641.0, train incorrect: 378.0, train accuracy: 0.9059467315673828
# valid total: 1005, valid correct: 784.0, valid incorrect: 221.0, valid accuracy: 0.7800995111465454
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.75      0.83      0.79       502
#         Fake       0.81      0.73      0.77       503
#
#     accuracy                           0.78      1005
#    macro avg       0.78      0.78      0.78      1005
# weighted avg       0.78      0.78      0.78      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [17:23,  2.07s/it]
# [[1821  189]
#  [ 170 1839]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.91      0.91      0.91      2010
#         Fake       0.91      0.92      0.91      2009
#
#     accuracy                           0.91      4019
#    macro avg       0.91      0.91      0.91      4019
# weighted avg       0.91      0.91      0.91      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 17, train loss: 0.20945311657099375, val loss: 0.836150139961983, executed in: 1302.0191416740417
# train total: 4019, train correct: 3660.0, train incorrect: 359.0, train accuracy: 0.9106742739677429
# valid total: 1005, valid correct: 786.0, valid incorrect: 219.0, valid accuracy: 0.7820895910263062
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.76      0.82      0.79       502
#         Fake       0.81      0.74      0.77       503
#
#     accuracy                           0.78      1005
#    macro avg       0.78      0.78      0.78      1005
# weighted avg       0.78      0.78      0.78      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [17:10,  2.05s/it]
# [[1804  206]
#  [ 176 1833]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.91      0.90      0.90      2010
#         Fake       0.90      0.91      0.91      2009
#
#     accuracy                           0.90      4019
#    macro avg       0.91      0.90      0.90      4019
# weighted avg       0.91      0.90      0.90      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 18, train loss: 0.2184391704028765, val loss: 0.8720230374019593, executed in: 1284.4079051017761
# train total: 4019, train correct: 3637.0, train incorrect: 382.0, train accuracy: 0.9049514532089233
# valid total: 1005, valid correct: 805.0, valid incorrect: 200.0, valid accuracy: 0.8009950518608093
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.79      0.82      0.81       502
#         Fake       0.82      0.78      0.80       503
#
#     accuracy                           0.80      1005
#    macro avg       0.80      0.80      0.80      1005
# weighted avg       0.80      0.80      0.80      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [16:58,  2.03s/it]
# [[1812  198]
#  [ 141 1868]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.93      0.90      0.91      2010
#         Fake       0.90      0.93      0.92      2009
#
#     accuracy                           0.92      4019
#    macro avg       0.92      0.92      0.92      4019
# weighted avg       0.92      0.92      0.92      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 19, train loss: 0.20017541128684715, val loss: 0.7991129514070169, executed in: 1275.9745762348175
# train total: 4019, train correct: 3680.0, train incorrect: 339.0, train accuracy: 0.9156506061553955
# valid total: 1005, valid correct: 798.0, valid incorrect: 207.0, valid accuracy: 0.7940298914909363
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.79      0.80      0.80       502
#         Fake       0.80      0.79      0.79       503
#
#     accuracy                           0.79      1005
#    macro avg       0.79      0.79      0.79      1005
# weighted avg       0.79      0.79      0.79      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 407it [14:11,  1.92s/it]

# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import datetime
import sys
import pandas as pd
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import torchvision
import gc


train_folders = ['/content/dfdc']
test_folders = ['/content/test_videos']

batch_size = int(8)
num_epochs = int(5)
n_frames = int(10)
lr = float(0.001)

TRAIN_FOLDERS = train_folders
TEST_FOLDERS = test_folders
print(f"all train folders: {train_folders}, {type(train_folders)}")
print(f"all test folders: {test_folders}, {type(test_folders)}")

gamma = 0.1
milestones = [6,12,18]

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = FaceClassifier()
model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_20_classifier_10_small.pt', map_location=device))
model = model.to(device)
class_weights = {0: 0.6191950464396285, 1: 10.1230}
weights_tensor = torch.tensor([class_weights[0], 10.1230], dtype=torch.float32).to(device)

# Modify the loss function
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=gamma)

start_time = datetime.datetime.now()
print(f'start time: {str(start_time)}')
print(f'using device: {device}')

'''Splitting into Train and Validation'''
train_dataset = FaceDeepfakeDataset(TRAIN_FOLDERS,  n_frames=n_frames, n_audio_reads=576, device=device, cache_folder="face_encode_cache")
test_dataset = FaceDeepfakeDatasetTest(TEST_FOLDERS, n_frames=n_frames, n_audio_reads=576, device=device,  cache_folder="face_encode_cache")

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
print(len(train_loader))


'''Train_Loop'''
train_losses = []
val_losses = []
best_loss = np.inf
train_accuracies = []
val_accuracies = []
epoch_times = []


for epoch in range(num_epochs):
    epoch_start_time = time.time()
    epoch_t_loss = 0
    epoch_v_loss = 0
    t_count = 0
    t_count_wrong = 0
    train_labels_all = []
    train_preds_all = []

    model.train()
    torch.cuda.empty_cache()
    gc.collect()
    for i, batch in tqdm(enumerate(train_loader)):
        torch.cuda.empty_cache()
        gc.collect()
        # if i * batch_size >= epoch_size:
        #     break
        video_data, labels = batch
        video_data = video_data.to(device)
        #audio_data = audio_data.to(device)

        output = model(video_data)
        loss = criterion(output, labels)

        output = torch.sigmoid(output)
        output = output.round()

        n_wrong = (labels - output).abs().sum()
        t_count_wrong += n_wrong
        t_count += labels.shape[0]

        epoch_t_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_labels_all.extend(labels.cpu().detach().numpy())
        train_preds_all.extend(output.cpu().detach().numpy())

        #print('.', end='', flush=True)
        torch.cuda.empty_cache()
        gc.collect()

    # Перетворіть на numpy-масиви
    train_labels_all = np.array(train_labels_all).astype(int)
    train_preds_all = np.array(train_preds_all).astype(int)

    # Обчисліть та виведіть матрицю плутанини для тренувального набору
    conf_matrix_train = confusion_matrix(train_labels_all, train_preds_all)
    print(conf_matrix_train)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix (Train Set)')
    plt.show()

    # Виведіть класифікаційний звіт для тренувального набору
    print("Classification Report (Train Set):")
    print(classification_report(train_labels_all, train_preds_all, target_names=['Real', 'Fake']))

    all_labels = []
    all_preds = []

    model.eval()
    with torch.no_grad():
        v_count = 0
        v_count_wrong = 0
        for i, batch in enumerate(val_loader):
            # if i * batch_size >= epoch_size:
        #        break
            torch.cuda.empty_cache()
            gc.collect()
            video_data, labels = batch
            video_data = video_data.to(device)
            #audio_data = audio_data.to(device)
            # optimizer.zero_grad()
            output = model(video_data)
            loss = criterion(output, labels)

            output = torch.sigmoid(output)
            output = output.round()
            n_wrong = (labels - output).abs().sum()
            v_count_wrong += n_wrong
            v_count += labels.shape[0]

            epoch_v_loss += loss.item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(output.cpu().numpy())

            # loss.backward()
            # optimizer.step()
            print('.', end='', flush=True)
            torch.cuda.empty_cache()
            gc.collect()

    epoch_end_time = time.time()
    epoch_exec_time = epoch_end_time - epoch_start_time
    epoch_times.append(epoch_exec_time)
    train_losses.append(epoch_t_loss/len(train_loader))
    val_losses.append(epoch_t_loss/len(val_loader))

    t_count_right = t_count - t_count_wrong
    v_count_right = v_count - v_count_wrong
    t_accuracy = t_count_right / t_count
    v_accuracy = v_count_right / v_count

    train_accuracies.append(t_accuracy)
    val_accuracies.append(v_accuracy)

    print(f'\nepoch: {epoch + 20}, train loss: {train_losses[-1]}, val loss: {val_losses[-1]}, executed in: {str(epoch_exec_time)}')
    print(f"train total: {t_count}, train correct: {t_count_right}, train incorrect: {t_count_wrong}, train accuracy: {t_accuracy}")
    print(f"valid total: {v_count}, valid correct: {v_count_right}, valid incorrect: {v_count_wrong}, valid accuracy: {v_accuracy}")
    all_labels = np.array(all_labels).astype(int)
    all_preds = np.array(all_preds).astype(int)
    # Обчислення та візуалізація матриці плутанини
    conf_matrix = confusion_matrix(all_labels, all_preds)
    #print(conf_matrix)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

    # Друк звіту про класифікацію
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=['Real', 'Fake']))

    scheduler.step()
    ### Saving model per best validation loss
    if best_loss > val_losses[-1]:
        best_loss = val_losses[-1]
        end_time = datetime.datetime.now()
        torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 21}_classifier_{n_frames}_small.pt')
    torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 21}_classifier_{n_frames}_small.pt')


end_time = datetime.datetime.now()
print(f"end time: {str(end_time)}")
exec_time = end_time - start_time
print(f"executed in: {str(exec_time)}")
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# all train folders: ['/content/dfdc'], <class 'list'>
# all test folders: ['/content/test_videos'], <class 'list'>
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 209MB/s]
# <ipython-input-22-8b92594be3da>:38: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_20_classifier_10_small.pt', map_location=device))
# start time: 2024-11-12 12:59:58.781377
# using device: cuda
# 503
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:79: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# /usr/local/lib/python3.10/dist-packages/facenet_pytorch/models/mtcnn.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(state_dict_path)
# 503it [1:40:22, 11.97s/it]
# [[1837  173]
#  [ 141 1868]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.93      0.91      0.92      2010
#         Fake       0.92      0.93      0.92      2009
#
#     accuracy                           0.92      4019
#    macro avg       0.92      0.92      0.92      4019
# weighted avg       0.92      0.92      0.92      4019
#
# ..............................................................................................................................
# epoch: 20, train loss: 0.1880498155599708, val loss: 0.7507068033862326, executed in: 7332.9478533267975
# train total: 4019, train correct: 3705.0, train incorrect: 314.0, train accuracy: 0.9218710660934448
# valid total: 1005, valid correct: 795.0, valid incorrect: 210.0, valid accuracy: 0.7910448312759399
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.78      0.80      0.79       502
#         Fake       0.80      0.78      0.79       503
#
#     accuracy                           0.79      1005
#    macro avg       0.79      0.79      0.79      1005
# weighted avg       0.79      0.79      0.79      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [17:32,  2.09s/it]
# [[1825  185]
#  [ 152 1857]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.92      0.91      0.92      2010
#         Fake       0.91      0.92      0.92      2009
#
#     accuracy                           0.92      4019
#    macro avg       0.92      0.92      0.92      4019
# weighted avg       0.92      0.92      0.92      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 21, train loss: 0.19584084401660734, val loss: 0.7818090836535991, executed in: 1316.2254254817963
# train total: 4019, train correct: 3682.0, train incorrect: 337.0, train accuracy: 0.9161482453346252
# valid total: 1005, valid correct: 779.0, valid incorrect: 226.0, valid accuracy: 0.7751244306564331
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.77      0.79      0.78       502
#         Fake       0.78      0.76      0.77       503
#
#     accuracy                           0.78      1005
#    macro avg       0.78      0.78      0.78      1005
# weighted avg       0.78      0.78      0.78      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [17:21,  2.07s/it]
# [[1836  174]
#  [ 147 1862]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.93      0.91      0.92      2010
#         Fake       0.91      0.93      0.92      2009
#
#     accuracy                           0.92      4019
#    macro avg       0.92      0.92      0.92      4019
# weighted avg       0.92      0.92      0.92      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 22, train loss: 0.1832410344894731, val loss: 0.7315098440333728, executed in: 1299.3751454353333
# train total: 4019, train correct: 3698.0, train incorrect: 321.0, train accuracy: 0.9201293587684631
# valid total: 1005, valid correct: 798.0, valid incorrect: 207.0, valid accuracy: 0.7940298914909363
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.80      0.79      0.79       502
#         Fake       0.79      0.80      0.80       503
#
#     accuracy                           0.79      1005
#    macro avg       0.79      0.79      0.79      1005
# weighted avg       0.79      0.79      0.79      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [17:27,  2.08s/it]
# [[1845  165]
#  [ 148 1861]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.93      0.92      0.92      2010
#         Fake       0.92      0.93      0.92      2009
#
#     accuracy                           0.92      4019
#    macro avg       0.92      0.92      0.92      4019
# weighted avg       0.92      0.92      0.92      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 23, train loss: 0.18573359204511755, val loss: 0.741460292053128, executed in: 1313.188892841339
# train total: 4019, train correct: 3706.0, train incorrect: 313.0, train accuracy: 0.9221199154853821
# valid total: 1005, valid correct: 786.0, valid incorrect: 219.0, valid accuracy: 0.7820895910263062
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.78      0.79      0.78       502
#         Fake       0.79      0.77      0.78       503
#
#     accuracy                           0.78      1005
#    macro avg       0.78      0.78      0.78      1005
# weighted avg       0.78      0.78      0.78      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 499it [17:18,  1.90s/it]

# %%
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import datetime
import sys
import pandas as pd
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import torchvision
import gc


train_folders = ['/content/dfdc']
test_folders = ['/content/test_videos']

batch_size = int(8)
num_epochs = int(4)
n_frames = int(10)
lr = float(0.001)

TRAIN_FOLDERS = train_folders
TEST_FOLDERS = test_folders
print(f"all train folders: {train_folders}, {type(train_folders)}")
print(f"all test folders: {test_folders}, {type(test_folders)}")

gamma = 0.1
milestones = [6,12,18]

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = FaceClassifier()
model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_24_classifier_10_small.pt', map_location=device))
model = model.to(device)
class_weights = {0: 0.6191950464396285, 1: 10.1230}
weights_tensor = torch.tensor([class_weights[0], 10.1230], dtype=torch.float32).to(device)

# Modify the loss function
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=gamma)

start_time = datetime.datetime.now()
print(f'start time: {str(start_time)}')
print(f'using device: {device}')

'''Splitting into Train and Validation'''
train_dataset = FaceDeepfakeDataset(TRAIN_FOLDERS,  n_frames=n_frames, n_audio_reads=576, device=device, cache_folder="face_encode_cache")
test_dataset = FaceDeepfakeDatasetTest(TEST_FOLDERS, n_frames=n_frames, n_audio_reads=576, device=device,  cache_folder="face_encode_cache")

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
print(len(train_loader))


'''Train_Loop'''
train_losses = []
val_losses = []
best_loss = np.inf
train_accuracies = []
val_accuracies = []
epoch_times = []


for epoch in range(num_epochs):
    epoch_start_time = time.time()
    epoch_t_loss = 0
    epoch_v_loss = 0
    t_count = 0
    t_count_wrong = 0
    train_labels_all = []
    train_preds_all = []

    model.train()
    torch.cuda.empty_cache()
    gc.collect()
    for i, batch in tqdm(enumerate(train_loader)):
        torch.cuda.empty_cache()
        gc.collect()
        # if i * batch_size >= epoch_size:
        #     break
        video_data, labels = batch
        video_data = video_data.to(device)
        #audio_data = audio_data.to(device)

        output = model(video_data)
        loss = criterion(output, labels)

        output = torch.sigmoid(output)
        output = output.round()

        n_wrong = (labels - output).abs().sum()
        t_count_wrong += n_wrong
        t_count += labels.shape[0]

        epoch_t_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_labels_all.extend(labels.cpu().detach().numpy())
        train_preds_all.extend(output.cpu().detach().numpy())

        #print('.', end='', flush=True)
        torch.cuda.empty_cache()
        gc.collect()

    # Перетворіть на numpy-масиви
    train_labels_all = np.array(train_labels_all).astype(int)
    train_preds_all = np.array(train_preds_all).astype(int)

    # Обчисліть та виведіть матрицю плутанини для тренувального набору
    conf_matrix_train = confusion_matrix(train_labels_all, train_preds_all)
    print(conf_matrix_train)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix (Train Set)')
    plt.show()

    # Виведіть класифікаційний звіт для тренувального набору
    print("Classification Report (Train Set):")
    print(classification_report(train_labels_all, train_preds_all, target_names=['Real', 'Fake']))

    all_labels = []
    all_preds = []

    model.eval()
    with torch.no_grad():
        v_count = 0
        v_count_wrong = 0
        for i, batch in enumerate(val_loader):
            # if i * batch_size >= epoch_size:
        #        break
            torch.cuda.empty_cache()
            gc.collect()
            video_data, labels = batch
            video_data = video_data.to(device)
            #audio_data = audio_data.to(device)
            # optimizer.zero_grad()
            output = model(video_data)
            loss = criterion(output, labels)

            output = torch.sigmoid(output)
            output = output.round()
            n_wrong = (labels - output).abs().sum()
            v_count_wrong += n_wrong
            v_count += labels.shape[0]

            epoch_v_loss += loss.item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(output.cpu().numpy())

            # loss.backward()
            # optimizer.step()
            print('.', end='', flush=True)
            torch.cuda.empty_cache()
            gc.collect()

    epoch_end_time = time.time()
    epoch_exec_time = epoch_end_time - epoch_start_time
    epoch_times.append(epoch_exec_time)
    train_losses.append(epoch_t_loss/len(train_loader))
    val_losses.append(epoch_t_loss/len(val_loader))

    t_count_right = t_count - t_count_wrong
    v_count_right = v_count - v_count_wrong
    t_accuracy = t_count_right / t_count
    v_accuracy = v_count_right / v_count

    train_accuracies.append(t_accuracy)
    val_accuracies.append(v_accuracy)

    print(f'\nepoch: {epoch + 24}, train loss: {train_losses[-1]}, val loss: {val_losses[-1]}, executed in: {str(epoch_exec_time)}')
    print(f"train total: {t_count}, train correct: {t_count_right}, train incorrect: {t_count_wrong}, train accuracy: {t_accuracy}")
    print(f"valid total: {v_count}, valid correct: {v_count_right}, valid incorrect: {v_count_wrong}, valid accuracy: {v_accuracy}")
    all_labels = np.array(all_labels).astype(int)
    all_preds = np.array(all_preds).astype(int)
    # Обчислення та візуалізація матриці плутанини
    conf_matrix = confusion_matrix(all_labels, all_preds)
    #print(conf_matrix)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

    # Друк звіту про класифікацію
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=['Real', 'Fake']))

    scheduler.step()
    ### Saving model per best validation loss
    if best_loss > val_losses[-1]:
        best_loss = val_losses[-1]
        end_time = datetime.datetime.now()
        torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 25}_classifier_{n_frames}_small.pt')
    torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 25}_classifier_{n_frames}_small.pt')


end_time = datetime.datetime.now()
print(f"end time: {str(end_time)}")
exec_time = end_time - start_time
print(f"executed in: {str(exec_time)}")
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# all train folders: ['/content/dfdc'], <class 'list'>
# all test folders: ['/content/test_videos'], <class 'list'>
# <ipython-input-23-6a308cae7b59>:38: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/content/dfdc_5k_train_test_split_b0_24_classifier_10_small.pt', map_location=device))
# start time: 2024-11-12 17:19:31.331284
# using device: cuda
# 503
# 2it [00:29, 14.13s/it]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [1:43:58, 12.40s/it]
# [[1848  162]
#  [ 132 1877]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.93      0.92      0.93      2010
#         Fake       0.92      0.93      0.93      2009
#
#     accuracy                           0.93      4019
#    macro avg       0.93      0.93      0.93      4019
# weighted avg       0.93      0.93      0.93      4019
#
# ..............................................................................................................................
# epoch: 24, train loss: 0.17714137500142735, val loss: 0.7071596160771266, executed in: 7558.56164598465
# train total: 4019, train correct: 3725.0, train incorrect: 294.0, train accuracy: 0.9268474578857422
# valid total: 1005, valid correct: 775.0, valid incorrect: 230.0, valid accuracy: 0.7711443305015564
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.74      0.82      0.78       502
#         Fake       0.80      0.72      0.76       503
#
#     accuracy                           0.77      1005
#    macro avg       0.77      0.77      0.77      1005
# weighted avg       0.77      0.77      0.77      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [17:25,  2.08s/it]
# [[1869  141]
#  [ 120 1889]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.94      0.93      0.93      2010
#         Fake       0.93      0.94      0.94      2009
#
#     accuracy                           0.94      4019
#    macro avg       0.94      0.94      0.94      4019
# weighted avg       0.94      0.94      0.94      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 25, train loss: 0.15982450497527395, val loss: 0.638029571448911, executed in: 1307.9060049057007
# train total: 4019, train correct: 3758.0, train incorrect: 261.0, train accuracy: 0.9350584149360657
# valid total: 1005, valid correct: 771.0, valid incorrect: 234.0, valid accuracy: 0.7671642303466797
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.74      0.82      0.78       502
#         Fake       0.80      0.71      0.75       503
#
#     accuracy                           0.77      1005
#    macro avg       0.77      0.77      0.77      1005
# weighted avg       0.77      0.77      0.77      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [17:27,  2.08s/it]
# [[1865  145]
#  [ 121 1888]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.94      0.93      0.93      2010
#         Fake       0.93      0.94      0.93      2009
#
#     accuracy                           0.93      4019
#    macro avg       0.93      0.93      0.93      4019
# weighted avg       0.93      0.93      0.93      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 26, train loss: 0.16795035603846872, val loss: 0.6704684848202362, executed in: 1305.5610754489899
# train total: 4019, train correct: 3753.0, train incorrect: 266.0, train accuracy: 0.9338143467903137
# valid total: 1005, valid correct: 791.0, valid incorrect: 214.0, valid accuracy: 0.7870647311210632
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.79      0.78      0.79       502
#         Fake       0.79      0.79      0.79       503
#
#     accuracy                           0.79      1005
#    macro avg       0.79      0.79      0.79      1005
# weighted avg       0.79      0.79      0.79      1005
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [17:32,  2.09s/it]
# [[1849  161]
#  [ 122 1887]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.94      0.92      0.93      2010
#         Fake       0.92      0.94      0.93      2009
#
#     accuracy                           0.93      4019
#    macro avg       0.93      0.93      0.93      4019
# weighted avg       0.93      0.93      0.93      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 27, train loss: 0.17367129123429018, val loss: 0.6933068213559362, executed in: 1320.037852048874
# train total: 4019, train correct: 3736.0, train incorrect: 283.0, train accuracy: 0.9295844435691833
# valid total: 1005, valid correct: 785.0, valid incorrect: 220.0, valid accuracy: 0.7810945510864258
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.77      0.80      0.79       502
#         Fake       0.79      0.76      0.78       503
#
#     accuracy                           0.78      1005
#    macro avg       0.78      0.78      0.78      1005
# weighted avg       0.78      0.78      0.78      1005
#
# end time: 2024-11-12 20:31:05.709656
# executed in: 3:11:34.378372
# Tesla T4
# Memory Usage:
# Allocated: 0.1 GB
# Cached:    0.2 GB
# <ipython-input-23-6a308cae7b59>:218: FutureWarning: `torch.cuda.memory_cached` has been renamed to `torch.cuda.memory_reserved`
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')

# %%
for epoch in range(1):
    epoch_start_time = time.time()
    epoch_t_loss = 0
    epoch_v_loss = 0
    t_count = 0
    t_count_wrong = 0
    train_labels_all = []
    train_preds_all = []

    model.train()
    torch.cuda.empty_cache()
    gc.collect()
    for i, batch in tqdm(enumerate(train_loader)):
        torch.cuda.empty_cache()
        gc.collect()
        # if i * batch_size >= epoch_size:
        #     break
        video_data, labels = batch
        video_data = video_data.to(device)
        #audio_data = audio_data.to(device)

        output = model(video_data)
        loss = criterion(output, labels)

        output = torch.sigmoid(output)
        output = output.round()

        n_wrong = (labels - output).abs().sum()
        t_count_wrong += n_wrong
        t_count += labels.shape[0]

        epoch_t_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_labels_all.extend(labels.cpu().detach().numpy())
        train_preds_all.extend(output.cpu().detach().numpy())

        #print('.', end='', flush=True)
        torch.cuda.empty_cache()
        gc.collect()

    # Перетворіть на numpy-масиви
    train_labels_all = np.array(train_labels_all).astype(int)
    train_preds_all = np.array(train_preds_all).astype(int)

    # Обчисліть та виведіть матрицю плутанини для тренувального набору
    conf_matrix_train = confusion_matrix(train_labels_all, train_preds_all)
    print(conf_matrix_train)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix (Train Set)')
    plt.show()

    # Виведіть класифікаційний звіт для тренувального набору
    print("Classification Report (Train Set):")
    print(classification_report(train_labels_all, train_preds_all, target_names=['Real', 'Fake']))

    all_labels = []
    all_preds = []

    model.eval()
    with torch.no_grad():
        v_count = 0
        v_count_wrong = 0
        for i, batch in enumerate(val_loader):
            # if i * batch_size >= epoch_size:
        #        break
            torch.cuda.empty_cache()
            gc.collect()
            video_data, labels = batch
            video_data = video_data.to(device)
            #audio_data = audio_data.to(device)
            # optimizer.zero_grad()
            output = model(video_data)
            loss = criterion(output, labels)

            output = torch.sigmoid(output)
            output = output.round()
            n_wrong = (labels - output).abs().sum()
            v_count_wrong += n_wrong
            v_count += labels.shape[0]

            epoch_v_loss += loss.item()

            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(output.cpu().numpy())

            # loss.backward()
            # optimizer.step()
            print('.', end='', flush=True)
            torch.cuda.empty_cache()
            gc.collect()

    epoch_end_time = time.time()
    epoch_exec_time = epoch_end_time - epoch_start_time
    epoch_times.append(epoch_exec_time)
    train_losses.append(epoch_t_loss/len(train_loader))
    val_losses.append(epoch_t_loss/len(val_loader))

    t_count_right = t_count - t_count_wrong
    v_count_right = v_count - v_count_wrong
    t_accuracy = t_count_right / t_count
    v_accuracy = v_count_right / v_count

    train_accuracies.append(t_accuracy)
    val_accuracies.append(v_accuracy)

    print(f'\nepoch: {epoch + 28}, train loss: {train_losses[-1]}, val loss: {val_losses[-1]}, executed in: {str(epoch_exec_time)}')
    print(f"train total: {t_count}, train correct: {t_count_right}, train incorrect: {t_count_wrong}, train accuracy: {t_accuracy}")
    print(f"valid total: {v_count}, valid correct: {v_count_right}, valid incorrect: {v_count_wrong}, valid accuracy: {v_accuracy}")
    all_labels = np.array(all_labels).astype(int)
    all_preds = np.array(all_preds).astype(int)
    # Обчислення та візуалізація матриці плутанини
    conf_matrix = confusion_matrix(all_labels, all_preds)
    #print(conf_matrix)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Real', 'Fake'], yticklabels=['Real', 'Fake'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()

    # Друк звіту про класифікацію
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=['Real', 'Fake']))

    scheduler.step()
    ### Saving model per best validation loss
    if best_loss > val_losses[-1]:
        best_loss = val_losses[-1]
        end_time = datetime.datetime.now()
        torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 29}_classifier_{n_frames}_small.pt')
    torch.save(model.state_dict(), f'/content/drive/MyDrive/experiments/dfdc_5k_train_test_split_b0_{epoch + 29}_classifier_{n_frames}_small.pt')

if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
# Out:
# 0it [00:00, ?it/s]<ipython-input-17-0d3d7818da70>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# 503it [17:41,  2.11s/it]
# [[1871  139]
#  [ 116 1893]]
# Classification Report (Train Set):
#               precision    recall  f1-score   support
#
#         Real       0.94      0.93      0.94      2010
#         Fake       0.93      0.94      0.94      2009
#
#     accuracy                           0.94      4019
#    macro avg       0.94      0.94      0.94      4019
# weighted avg       0.94      0.94      0.94      4019
# <ipython-input-19-0ee26e648c0f>:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(cache_path)
# ..............................................................................................................................
# epoch: 28, train loss: 0.15364820341196347, val loss: 0.6133733834620447, executed in: 1325.8014492988586
# train total: 4019, train correct: 3764.0, train incorrect: 255.0, train accuracy: 0.9365513324737549
# valid total: 1005, valid correct: 768.0, valid incorrect: 237.0, valid accuracy: 0.7641791105270386
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       0.73      0.83      0.78       502
#         Fake       0.80      0.70      0.75       503
#
#     accuracy                           0.76      1005
#    macro avg       0.77      0.76      0.76      1005
# weighted avg       0.77      0.76      0.76      1005
#
# Tesla T4
# Memory Usage:
# Allocated: 0.2 GB
# Cached:    0.3 GB
# <ipython-input-25-1aa340c40fa0>:144: FutureWarning: `torch.cuda.memory_cached` has been renamed to `torch.cuda.memory_reserved`
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
